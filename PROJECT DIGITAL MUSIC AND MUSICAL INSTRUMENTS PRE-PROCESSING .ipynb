# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\archit\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in c:\users\archit\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in c:\users\archit\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\archit\anaconda3\lib\site-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\archit\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\archit\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\archit\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\archit\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\archit\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\archit\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\archit\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# ## &#10148;Problem Statement </br>
# ### <div class="alert alert-info">Thomas, a global market analyst, wishes to develop an automated system to analyze and monitor an enormous number of reviews. By monitoring the entire review history of products, he wishes to analyze tone, language, keywords, and trends over time to provide valuable insights that increase the success rate of existing and new products and marketing campaigns.</div>

# %% [markdown]
# ## Introduction
#
# Everyday we come across various products in our lives, on the digital medium we swipe across hundreds of product choices under one category. It will be tedious for the customer to make selection. Here comes 'reviews' where customers who have already got that product leave a rating after using them and brief their experience by giving reviews. As we know ratings can be easily sorted and judged whether a product is good or bad. But when it comes to sentence reviews we need to read through every line to make sure the review conveys a positive or negative sense. In the era of artificial intelligence, things like that have got easy with the Natural Langauge Processing(NLP) technology.

# %% [markdown]
# ## &#10148; Requried Libraries</br>

# %% [markdown]
# - Importing the required libraries for the project

# %%
import pandas as pd
import json
import csv
import gzip
import itertools
import string
import re
#import wordcloud
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import pylab as pl
from textblob import TextBlob
import spacy                                                  # Import spaCy library
from spacy.lang.en import English                             # Import specific model
nlp = spacy.load("en_core_web_sm")
import warnings                                                  #To avoid the shown warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# - The gzip module provides the GzipFile class, as well as the open() , compress() and decompress() convenience functions.
#
# - The Yield keyword in Python is similar to a return statement used for returning values or objects in Python.

# %% [markdown]
# ## &#10148; Importing the Data</br>

# %%
reviews = pd.read_json('Digital_Music.json.gz', lines=True)
metadata = pd.read_json('meta_Digital_Music.json.gz', lines=True)

# %%
reviews.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True  12 22, 2013  A1ZCPG3D3HGRSS  0001388703
# 1        5      True  09 11, 2013   AC2PL52NKPL29  0001388703
# 2        5      True   03 2, 2013  A1SUZXBDZSDQ3A  0001388703
# 3        5      True   12 2, 2012  A3A0W7FZXM0IZW  0001388703
# 4        5     False   01 7, 2012  A12R54MKO17TW0  0001388703
#
#                       style        reviewerName  \
# 0  {'Format:': ' Audio CD'}      mark l. massey
# 1  {'Format:': ' Audio CD'}        Norma Mushen
# 2  {'Format:': ' Audio CD'}  Herbert W. Shurley
# 3  {'Format:': ' Audio CD'}      Mary M Raybell
# 4  {'Format:': ' Audio CD'}            J. Bynum
#
#                                           reviewText  \
# 0  This is a great cd full of worship favorites!!...
# 1  So creative!  Love his music - the words, the ...
# 2  Keith Green, gone far to early in his carreer,...
# 3  Keith Green had his special comedy style of Ch...
# 4  Keith Green / So you wanna go back to Egypt......
#
#                                              summary  unixReviewTime vote  \
# 0                                   Great worship cd      1387670400  NaN
# 1                              Gotta listen to this!      1378857600  NaN
# 2          Great approach still gets the message out      1362182400  NaN
# 3                                  Great A must have      1354406400  NaN
# 4  A great one from Keith with a guest appearance...      1325894400    6
#
#   image
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
metadata.head()
# Out:
#   category tech1                                        description fit  \
# 0       []                                                       []
# 1       []                                                       []
# 2       []                                                       []
# 3       []                                                       []
# 4       []        [1. Losing Game 2. I Can't Wait 3. Didn't He S...
#
#                                title  \
# 0       Master Collection Volume One
# 1  Hymns Collection: Hymns 1 &amp; 2
# 2        Early Works - Don Francisco
# 3      So You Wanna Go Back to Egypt
# 4          Early Works - Dallas Holm
#
#                                             also_buy tech2  \
# 0  [B000002UEN, B000008LD5, B01J804JKE, 747403435...
# 1                           [5558154950, B00014K5V4]
# 2  [B00004RC05, B003H8F4NA, B003ZFVHPO, B003JMP1Z...
# 3  [B0000275QQ, 0001393774, 0001388312, B0016CP2G...
# 4  [B0002N4JP2, 0760131694, B00002EQ79, B00150K8J...
#
#                     brand feature                      rank  \
# 0     John Michael Talbot      []   58,291 in CDs & Vinyl (
# 1  Second Chapter of Acts      []   93,164 in CDs & Vinyl (
# 2           Don Francisco      []  875,825 in CDs & Vinyl (
# 3             Keith Green      []  203,263 in CDs & Vinyl (
# 4             Dallas Holm      []  399,269 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B000002UEN, B000008LD5, 7474034352, B000008LD...
# 1  [B000008KJ3, B000008KJ0, 5558154950, B000UN8KZ...
# 2  [B003H8F4NA, B003ZFVHPO, B003JMP1ZK, B00004RC0...
# 3  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 4  [B0002N4JP2, 0760131694, B00150K8JC, B003MTXNV...
#
#                                             main_cat similar_item date  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#     price        asin imageURL imageURLHighRes details
# 0  $18.99  0001377647       []              []     NaN
# 1          0001529145       []              []     NaN
# 2          0001527134       []              []     NaN
# 3  $13.01  0001388703       []              []     NaN
# 4          0001526146       []              []     NaN

# %% [markdown]
# - Shape of review data
# - Columns of review data
# - Statistical evualtion of the review data
# - Data type of review data

# %%
print('Shape of review data:\n',reviews.shape)
print('\n')
print('#'*100,'\n')
print('Columns of review data:\n ',reviews.columns)
print('\n')
print('#'*100,'\n')
print('Statistical evualtion of the review data:\n',reviews.describe())
print('\n')
print('#'*100,'\n')
print('Data type of review data:\n',reviews.dtypes)
# Out:
# Shape of review data:
#  (1584082, 12)
#
#
# ####################################################################################################
#
# Columns of review data:
#   Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin', 'style',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'image'],
#       dtype='object')
#
#
# ####################################################################################################
#
# Statistical evualtion of the review data:
#              overall  unixReviewTime
# count  1.584082e+06    1.584082e+06
# mean   4.660555e+00    1.408211e+09
# std    8.440314e-01    7.857646e+07
# min    1.000000e+00    8.773056e+08
# 25%    5.000000e+00    1.374883e+09
# 50%    5.000000e+00    1.420070e+09
# 75%    5.000000e+00    1.457222e+09
# max    5.000000e+00    1.538438e+09
#
#
# ####################################################################################################
#
# Data type of review data:
#  overall            int64
# verified            bool
# reviewTime        object
# reviewerID        object
# asin              object
# style             object
# reviewerName      object
# reviewText        object
# summary           object
# unixReviewTime     int64
# vote              object
# image             object
# dtype: object

# %%
metadata.shape
# Out:
# (74347, 19)

# %% [markdown]
# - Shape of meta data
# - Columns of meta data
# - Statistical evualtion of the meta data
# - Data type of meta data

# %%
print('Shape of meta data:\n',metadata.shape)
print('\n')
print('#'*100,'\n')
print('Columns of meta data:\n ',metadata.columns)
print('\n')
print('#'*100,'\n')
print('Data type of meta data:\n',metadata.dtypes)
# Out:
# Shape of meta data:
#  (74347, 19)
#
#
# ####################################################################################################
#
# Columns of meta data:
#   Index(['category', 'tech1', 'description', 'fit', 'title', 'also_buy', 'tech2',
#        'brand', 'feature', 'rank', 'also_view', 'main_cat', 'similar_item',
#        'date', 'price', 'asin', 'imageURL', 'imageURLHighRes', 'details'],
#       dtype='object')
#
#
# ####################################################################################################
#
# Data type of meta data:
#  category           object
# tech1              object
# description        object
# fit                object
# title              object
# also_buy           object
# tech2              object
# brand              object
# feature            object
# rank               object
# also_view          object
# main_cat           object
# similar_item       object
# date               object
# price              object
# asin               object
# imageURL           object
# imageURLHighRes    object
# details            object
# dtype: object

# %% [markdown]
# ## Merging both the datasets of review and metadata for  analysis

# %%
digi_muse = pd.merge(reviews,metadata,on='asin')

# %%
digi_muse.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True  12 22, 2013  A1ZCPG3D3HGRSS  0001388703
# 1        5      True  09 11, 2013   AC2PL52NKPL29  0001388703
# 2        5      True   03 2, 2013  A1SUZXBDZSDQ3A  0001388703
# 3        5      True   12 2, 2012  A3A0W7FZXM0IZW  0001388703
# 4        5     False   01 7, 2012  A12R54MKO17TW0  0001388703
#
#                       style        reviewerName  \
# 0  {'Format:': ' Audio CD'}      mark l. massey
# 1  {'Format:': ' Audio CD'}        Norma Mushen
# 2  {'Format:': ' Audio CD'}  Herbert W. Shurley
# 3  {'Format:': ' Audio CD'}      Mary M Raybell
# 4  {'Format:': ' Audio CD'}            J. Bynum
#
#                                           reviewText  \
# 0  This is a great cd full of worship favorites!!...
# 1  So creative!  Love his music - the words, the ...
# 2  Keith Green, gone far to early in his carreer,...
# 3  Keith Green had his special comedy style of Ch...
# 4  Keith Green / So you wanna go back to Egypt......
#
#                                              summary  unixReviewTime  ...  \
# 0                                   Great worship cd      1387670400  ...
# 1                              Gotta listen to this!      1378857600  ...
# 2          Great approach still gets the message out      1362182400  ...
# 3                                  Great A must have      1354406400  ...
# 4  A great one from Keith with a guest appearance...      1325894400  ...
#
#   feature                      rank  \
# 0      []  203,263 in CDs & Vinyl (
# 1      []  203,263 in CDs & Vinyl (
# 2      []  203,263 in CDs & Vinyl (
# 3      []  203,263 in CDs & Vinyl (
# 4      []  203,263 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 1  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 2  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 3  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 4  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
#
#                                             main_cat similar_item date  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#     price imageURL imageURLHighRes details
# 0  $13.01       []              []     NaN
# 1  $13.01       []              []     NaN
# 2  $13.01       []              []     NaN
# 3  $13.01       []              []     NaN
# 4  $13.01       []              []     NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# - Shape of merge data(digi_muse)
# - Columns of merge data(digi_muse)
# - Data type of merge data(digi_muse)

# %%
print('Shape of merge data:\n',digi_muse.shape)
print('\n')
print('#'*100,'\n')
print('Columns of merge data:\n ',digi_muse.columns)
print('\n')
print('#'*100,'\n')
print('Data type of merge data:\n',digi_muse.info())
# Out:
# Shape of merge data:
#  (182826, 30)
#
#
# ####################################################################################################
#
# Columns of merge data:
#   Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin', 'style',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'image', 'category', 'tech1', 'description', 'fit', 'title', 'also_buy',
#        'tech2', 'brand', 'feature', 'rank', 'also_view', 'main_cat',
#        'similar_item', 'date', 'price', 'imageURL', 'imageURLHighRes',
#        'details'],
#       dtype='object')
#
#
# ####################################################################################################
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182826 entries, 0 to 182825
# Data columns (total 30 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   overall          182826 non-null  int64
#  1   verified         182826 non-null  bool
#  2   reviewTime       182826 non-null  object
#  3   reviewerID       182826 non-null  object
#  4   asin             182826 non-null  object
#  5   style            143434 non-null  object
#  6   reviewerName     182803 non-null  object
#  7   reviewText       182736 non-null  object
#  8   summary          182770 non-null  object
#  9   unixReviewTime   182826 non-null  int64
#  10  vote             37009 non-null   object
#  11  image            3686 non-null    object
#  12  category         182826 non-null  object
#  13  tech1            182826 non-null  object
#  14  description      182826 non-null  object
#  15  fit              182826 non-null  object
#  16  title            182826 non-null  object
#  17  also_buy         182826 non-null  object
#  18  tech2            182826 non-null  object
#  19  brand            182826 non-null  object
#  20  feature          182826 non-null  object
#  21  rank             182826 non-null  object
#  22  also_view        182826 non-null  object
#  23  main_cat         182826 non-null  object
#  24  similar_item     182826 non-null  object
#  25  date             182826 non-null  object
#  26  price            182826 non-null  object
#  27  imageURL         182826 non-null  object
#  28  imageURLHighRes  182826 non-null  object
#  29  details          179665 non-null  object
# dtypes: bool(1), int64(2), object(27)
# memory usage: 42.0+ MB
# Data type of merge data:
#  None

# %%
digi_muse_c=digi_muse.copy()

# %% [markdown]
# ### Checking for missing values in our merged data (digi_muse).

# %%
digi_muse_c.isnull().sum()
# Out:
# overall                 0
# verified                0
# reviewTime              0
# reviewerID              0
# asin                    0
# style               39392
# reviewerName           23
# reviewText             90
# summary                56
# unixReviewTime          0
# vote               145817
# image              179140
# category                0
# tech1                   0
# description             0
# fit                     0
# title                   0
# also_buy                0
# tech2                   0
# brand                   0
# feature                 0
# rank                    0
# also_view               0
# main_cat                0
# similar_item            0
# date                    0
# price                   0
# imageURL                0
# imageURLHighRes         0
# details              3161
# dtype: int64

# %% [markdown]
# ## Percentage of null values.

# %%
digi_muse_c.isnull().sum()/len(digi_muse)*100
# Out:
# overall             0.000000
# verified            0.000000
# reviewTime          0.000000
# reviewerID          0.000000
# asin                0.000000
# style              21.546170
# reviewerName        0.012580
# reviewText          0.049227
# summary             0.030630
# unixReviewTime      0.000000
# vote               79.757256
# image              97.983875
# category            0.000000
# tech1               0.000000
# description         0.000000
# fit                 0.000000
# title               0.000000
# also_buy            0.000000
# tech2               0.000000
# brand               0.000000
# feature             0.000000
# rank                0.000000
# also_view           0.000000
# main_cat            0.000000
# similar_item        0.000000
# date                0.000000
# price               0.000000
# imageURL            0.000000
# imageURLHighRes     0.000000
# details             1.728966
# dtype: float64

# %% [markdown]
# ### Looking at the percentage of null values in the columns:- vote, image has high % of null value so i removed this columns from our merge data(digi_muse)

# %%
digi_muse_c.drop(['image','vote'],axis=1 ,inplace=True)
#digi_muse_c = digi_muse_c.drop(columns='vote')

# %%
digi_muse_c.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True  12 22, 2013  A1ZCPG3D3HGRSS  0001388703
# 1        5      True  09 11, 2013   AC2PL52NKPL29  0001388703
# 2        5      True   03 2, 2013  A1SUZXBDZSDQ3A  0001388703
# 3        5      True   12 2, 2012  A3A0W7FZXM0IZW  0001388703
# 4        5     False   01 7, 2012  A12R54MKO17TW0  0001388703
#
#                       style        reviewerName  \
# 0  {'Format:': ' Audio CD'}      mark l. massey
# 1  {'Format:': ' Audio CD'}        Norma Mushen
# 2  {'Format:': ' Audio CD'}  Herbert W. Shurley
# 3  {'Format:': ' Audio CD'}      Mary M Raybell
# 4  {'Format:': ' Audio CD'}            J. Bynum
#
#                                           reviewText  \
# 0  This is a great cd full of worship favorites!!...
# 1  So creative!  Love his music - the words, the ...
# 2  Keith Green, gone far to early in his carreer,...
# 3  Keith Green had his special comedy style of Ch...
# 4  Keith Green / So you wanna go back to Egypt......
#
#                                              summary  unixReviewTime  ...  \
# 0                                   Great worship cd      1387670400  ...
# 1                              Gotta listen to this!      1378857600  ...
# 2          Great approach still gets the message out      1362182400  ...
# 3                                  Great A must have      1354406400  ...
# 4  A great one from Keith with a guest appearance...      1325894400  ...
#
#   feature                      rank  \
# 0      []  203,263 in CDs & Vinyl (
# 1      []  203,263 in CDs & Vinyl (
# 2      []  203,263 in CDs & Vinyl (
# 3      []  203,263 in CDs & Vinyl (
# 4      []  203,263 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 1  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 2  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 3  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 4  [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
#
#                                             main_cat similar_item date  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#     price imageURL imageURLHighRes details
# 0  $13.01       []              []     NaN
# 1  $13.01       []              []     NaN
# 2  $13.01       []              []     NaN
# 3  $13.01       []              []     NaN
# 4  $13.01       []              []     NaN
#
# [5 rows x 28 columns]

# %%
digi_muse_c.shape
# Out:
# (182826, 28)

# %% [markdown]
# ### Removing all the null values from the containig columns of Null Values.

# %%
for col in digi_muse_c.columns:
    digi_muse_c = digi_muse_c[~pd.isnull(digi_muse_c['style'])]
    
for col in digi_muse_c.columns:
    digi_muse_c = digi_muse_c[~pd.isnull(digi_muse_c['reviewerName'])]
    
for col in digi_muse_c.columns:
    digi_muse_c = digi_muse_c[~pd.isnull(digi_muse_c['reviewText'])]
    
for col in digi_muse_c.columns:
    digi_muse_c = digi_muse_c[~pd.isnull(digi_muse_c['summary'])]
    
for col in digi_muse_c.columns:
    digi_muse_c = digi_muse_c[~pd.isnull(digi_muse_c['details'])]

# %%
digi_muse_c.shape
# Out:
# (140833, 28)

# %%
print('Old data shape =>\n',digi_muse.shape)
print('#'*100)
print('New data shape =>\n',digi_muse_c.shape)
# Out:
# Old data shape =>
#  (182826, 30)
# ####################################################################################################
# New data shape =>
#  (140833, 28)

# %% [markdown]
# ### Cheack Null value

# %%
digi_muse_c.isnull().sum()
# Out:
# overall            0
# verified           0
# reviewTime         0
# reviewerID         0
# asin               0
# style              0
# reviewerName       0
# reviewText         0
# summary            0
# unixReviewTime     0
# category           0
# tech1              0
# description        0
# fit                0
# title              0
# also_buy           0
# tech2              0
# brand              0
# feature            0
# rank               0
# also_view          0
# main_cat           0
# similar_item       0
# date               0
# price              0
# imageURL           0
# imageURLHighRes    0
# details            0
# dtype: int64

# %% [markdown]
# ### There are no missing value left

# %% [markdown]
# # Drop irrelevant columns

# %% [markdown]
# ### What Is  Unix Time?

# %% [markdown]
# ###### Unix time is a count of total seconds since a fixed time and date. It’s a date/time (or timestamp) format that looks different from the human-readable dates and times we’re used to. This is purely for efficiency reasons. It takes a lot less space to store a single number representing seconds than it does to store separate values for the year, month, hour, etc.

# %%
cols = ['fit', 'tech2','tech1', 'feature', 'details', 'date','imageURL', 'imageURLHighRes','unixReviewTime']

for i in cols:
    digi_muse_c.drop([i],axis=1,inplace=True)

# %%
print('New data shape after drop some irrelevant:\n',digi_muse_c.shape)
# Out:
# New data shape after drop some irrelevant:
#  (140833, 19)

# %%
print('Columns of New data:\n ',digi_muse_c.columns)
# Out:
# Columns of New data:
#   Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin', 'style',
#        'reviewerName', 'reviewText', 'summary', 'category', 'description',
#        'title', 'also_buy', 'brand', 'rank', 'also_view', 'main_cat',
#        'similar_item', 'price'],
#       dtype='object')

# %%
digi_muse_c.reset_index(drop=True,inplace=True)
digi_muse_c.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True  12 12, 2014  A2KLYLMS27MMSX  7019098606
# 1        5      True   12 9, 2014  A1IOEZDAZD6X51  7019098606
# 2        5      True   12 5, 2014  A1LUTAW6O69PQP  7019098606
# 3        5      True  09 29, 2014  A1UUCVS78RELYW  7019098606
# 4        5      True   09 6, 2014  A1E2OY42QMGRXR  7019098606
#
#                             style         reviewerName  \
# 0        {'Format:': ' Audio CD'}            C. oliver
# 1        {'Format:': ' Audio CD'}                  Raf
# 2        {'Format:': ' Audio CD'}  Paula Milo-Moultrie
# 3        {'Format:': ' Audio CD'}             jadamtam
# 4  {'Format:': ' Audio Cassette'}       Chester Thrash
#
#                                           reviewText  \
# 0  Brooklyn Tab can not be beat in gospel music. ...
# 1                                             Great!
# 2  Their music is always inspiring! I enjoy liste...
# 3                                    Beautiful songs
# 4        It's one of my favorites! I really love it!
#
#                                              summary category description  \
# 0                                          Uplifting       []          []
# 1                                         Five Stars       []          []
# 2  I enjoy listening to it as well as and singing...       []          []
# 3                                         Five Stars       []          []
# 4                                  I really love it!       []          []
#
#           title                                           also_buy  \
# 0  Live...Again  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 1  Live...Again  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 2  Live...Again  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 3  Live...Again  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 4  Live...Again  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
#
#                        brand                      rank  \
# 0  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 1  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 2  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 3  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 4  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 1  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 2  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 3  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 4  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
#
#                                             main_cat similar_item   price
# 0  <img src="https://images-na.ssl-images-amazon....               $13.71
# 1  <img src="https://images-na.ssl-images-amazon....               $13.71
# 2  <img src="https://images-na.ssl-images-amazon....               $13.71
# 3  <img src="https://images-na.ssl-images-amazon....               $13.71
# 4  <img src="https://images-na.ssl-images-amazon....               $13.71

# %% [markdown]
# ### Reformat date time from raw form

# %%
digi_muse_c["reviewTime"] = pd.to_datetime(digi_muse_c["reviewTime"])

# %%
digi_muse_c.head()
# Out:
#    overall  verified reviewTime      reviewerID        asin  \
# 0        5      True 2014-12-12  A2KLYLMS27MMSX  7019098606
# 1        5      True 2014-12-09  A1IOEZDAZD6X51  7019098606
# 2        5      True 2014-12-05  A1LUTAW6O69PQP  7019098606
# 3        5      True 2014-09-29  A1UUCVS78RELYW  7019098606
# 4        5      True 2014-09-06  A1E2OY42QMGRXR  7019098606
#
#                             style         reviewerName  \
# 0        {'Format:': ' Audio CD'}            C. oliver
# 1        {'Format:': ' Audio CD'}                  Raf
# 2        {'Format:': ' Audio CD'}  Paula Milo-Moultrie
# 3        {'Format:': ' Audio CD'}             jadamtam
# 4  {'Format:': ' Audio Cassette'}       Chester Thrash
#
#                                           reviewText  \
# 0  Brooklyn Tab can not be beat in gospel music. ...
# 1                                             Great!
# 2  Their music is always inspiring! I enjoy liste...
# 3                                    Beautiful songs
# 4        It's one of my favorites! I really love it!
#
#                                              summary category description  \
# 0                                          Uplifting       []          []
# 1                                         Five Stars       []          []
# 2  I enjoy listening to it as well as and singing...       []          []
# 3                                         Five Stars       []          []
# 4                                  I really love it!       []          []
#
#           title                                           also_buy  \
# 0  Live...Again  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 1  Live...Again  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 2  Live...Again  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 3  Live...Again  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 4  Live...Again  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
#
#                        brand                      rank  \
# 0  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 1  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 2  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 3  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 4  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
#
#                                            also_view  \
# 0  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 1  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 2  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 3  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 4  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
#
#                                             main_cat similar_item   price
# 0  <img src="https://images-na.ssl-images-amazon....               $13.71
# 1  <img src="https://images-na.ssl-images-amazon....               $13.71
# 2  <img src="https://images-na.ssl-images-amazon....               $13.71
# 3  <img src="https://images-na.ssl-images-amazon....               $13.71
# 4  <img src="https://images-na.ssl-images-amazon....               $13.71

# %%
digi_muse_c = digi_muse_c[['asin', 'summary', 'reviewText','description', 'title','overall','brand','rank','verified', 'reviewerID', 'reviewerName', 'reviewTime',
                    'price','style','category','also_buy','also_view','main_cat','similar_item']]

# %%
digi_muse_c.head()
# Out:
#          asin                                            summary  \
# 0  7019098606                                          Uplifting
# 1  7019098606                                         Five Stars
# 2  7019098606  I enjoy listening to it as well as and singing...
# 3  7019098606                                         Five Stars
# 4  7019098606                                  I really love it!
#
#                                           reviewText description  \
# 0  Brooklyn Tab can not be beat in gospel music. ...          []
# 1                                             Great!          []
# 2  Their music is always inspiring! I enjoy liste...          []
# 3                                    Beautiful songs          []
# 4        It's one of my favorites! I really love it!          []
#
#           title  overall                      brand                      rank  \
# 0  Live...Again        5  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 1  Live...Again        5  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 2  Live...Again        5  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 3  Live...Again        5  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
# 4  Live...Again        5  Brooklyn Tabernacle Choir  725,231 in CDs & Vinyl (
#
#    verified      reviewerID         reviewerName reviewTime   price  \
# 0      True  A2KLYLMS27MMSX            C. oliver 2014-12-12  $13.71
# 1      True  A1IOEZDAZD6X51                  Raf 2014-12-09  $13.71
# 2      True  A1LUTAW6O69PQP  Paula Milo-Moultrie 2014-12-05  $13.71
# 3      True  A1UUCVS78RELYW             jadamtam 2014-09-29  $13.71
# 4      True  A1E2OY42QMGRXR       Chester Thrash 2014-09-06  $13.71
#
#                             style category  \
# 0        {'Format:': ' Audio CD'}       []
# 1        {'Format:': ' Audio CD'}       []
# 2        {'Format:': ' Audio CD'}       []
# 3        {'Format:': ' Audio CD'}       []
# 4  {'Format:': ' Audio Cassette'}       []
#
#                                             also_buy  \
# 0  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 1  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 2  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 3  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 4  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
#
#                                            also_view  \
# 0  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 1  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 2  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 3  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 4  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
#
#                                             main_cat similar_item
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....

# %%
digi_muse_c.shape
# Out:
# (140833, 19)

# %% [markdown]
# ### Check Duplicate value

# %%
#find duplicate rows across  columns
digi_muse_c.duplicated(['asin','reviewText','reviewerName','reviewerID']).sum()
# Out:
# 17188

# %%
digi_muse_c.drop_duplicates(subset=['asin','reviewText','reviewerName','reviewerID'], keep='first',inplace=True)

# %%
#find duplicate rows across  columns
digi_muse_c.duplicated(['asin','reviewText','reviewerName','reviewerID']).sum()
# Out:
# 0

# %%
print('New data shape after drop duplicate value:\n',digi_muse_c.shape)
# Out:
# New data shape after drop duplicate value:
#  (123645, 19)

# %%
digi_muse_c[['rank']]
# Out:
#                             rank
# 0       725,231 in CDs & Vinyl (
# 1       725,231 in CDs & Vinyl (
# 2       725,231 in CDs & Vinyl (
# 3       725,231 in CDs & Vinyl (
# 4       725,231 in CDs & Vinyl (
# ...                          ...
# 140828  130,165 in CDs & Vinyl (
# 140829  130,165 in CDs & Vinyl (
# 140830  130,165 in CDs & Vinyl (
# 140831  130,165 in CDs & Vinyl (
# 140832                        []
#
# [123645 rows x 1 columns]

# %%
#for column 'rank' 
#remove uneccessary symbol like comma ',' and words
#convert the string into integer 
digi_muse_c['rank'].replace(',','', regex=True, inplace=True)
digi_muse_c['rank'] = digi_muse_c['rank'].str.extract('(\d+)')

# %%
digi_muse_c[['rank']]
# Out:
#           rank
# 0       725231
# 1       725231
# 2       725231
# 3       725231
# 4       725231
# ...        ...
# 140828  130165
# 140829  130165
# 140830  130165
# 140831  130165
# 140832     NaN
#
# [123645 rows x 1 columns]

# %%
digi_muse_c[['price']]
# Out:
#          price
# 0       $13.71
# 1       $13.71
# 2       $13.71
# 3       $13.71
# 4       $13.71
# ...        ...
# 140828
# 140829
# 140830
# 140831
# 140832
#
# [123645 rows x 1 columns]

# %%
digi_muse_c['price'].unique
# Out:
# <bound method Series.unique of 0         $13.71
# 1         $13.71
# 2         $13.71
# 3         $13.71
# 4         $13.71
#            ...
# 140828
# 140829
# 140830
# 140831
# 140832
# Name: price, Length: 123645, dtype: object>

# %%
#for column 'price'
#if 'price' don't start with $ or has '-' means null value, fillna with 'unknown'
#remove uneccessary symbol like comma ',' and '$'
#product_table.loc[product_table["price"].str[0] != "$", "price"] = "unknown"
#product_table.loc[product_table["price"].str.contains('-'), "price"] = "unknown"
digi_muse_c['price'].replace("\$","", regex=True, inplace=True)
digi_muse_c['price'].replace(',','', regex=True, inplace=True)

# %%
print("Number of reviews having empty string :",digi_muse_c[digi_muse_c['price']==''].shape[0])
# Out:
# Number of reviews having empty string : 41141

# %%
digi_muse_c.isnull().sum()
# Out:
# asin               0
# summary            0
# reviewText         0
# description        0
# title              0
# overall            0
# brand              0
# rank            4456
# verified           0
# reviewerID         0
# reviewerName       0
# reviewTime         0
# price              0
# style              0
# category           0
# also_buy           0
# also_view          0
# main_cat           0
# similar_item       0
# dtype: int64

# %%
digi_muse_c.dropna(inplace=True)

# %%
digi_muse_c.isnull().sum()
# Out:
# asin            0
# summary         0
# reviewText      0
# description     0
# title           0
# overall         0
# brand           0
# rank            0
# verified        0
# reviewerID      0
# reviewerName    0
# reviewTime      0
# price           0
# style           0
# category        0
# also_buy        0
# also_view       0
# main_cat        0
# similar_item    0
# dtype: int64

# %%
digi_muse_c = digi_muse_c[digi_muse_c['price']!='']

# %%
print("Number of reviews having empty string :",digi_muse_c[digi_muse_c['price']==''].shape[0])
# Out:
# Number of reviews having empty string : 0

# %%
digi_muse_c.head()
# Out:
#          asin                                            summary  \
# 0  7019098606                                          Uplifting
# 1  7019098606                                         Five Stars
# 2  7019098606  I enjoy listening to it as well as and singing...
# 3  7019098606                                         Five Stars
# 4  7019098606                                  I really love it!
#
#                                           reviewText description  \
# 0  Brooklyn Tab can not be beat in gospel music. ...          []
# 1                                             Great!          []
# 2  Their music is always inspiring! I enjoy liste...          []
# 3                                    Beautiful songs          []
# 4        It's one of my favorites! I really love it!          []
#
#           title  overall                      brand    rank  verified  \
# 0  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 1  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 2  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 3  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 4  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
#
#        reviewerID         reviewerName reviewTime  price  \
# 0  A2KLYLMS27MMSX            C. oliver 2014-12-12  13.71
# 1  A1IOEZDAZD6X51                  Raf 2014-12-09  13.71
# 2  A1LUTAW6O69PQP  Paula Milo-Moultrie 2014-12-05  13.71
# 3  A1UUCVS78RELYW             jadamtam 2014-09-29  13.71
# 4  A1E2OY42QMGRXR       Chester Thrash 2014-09-06  13.71
#
#                             style category  \
# 0        {'Format:': ' Audio CD'}       []
# 1        {'Format:': ' Audio CD'}       []
# 2        {'Format:': ' Audio CD'}       []
# 3        {'Format:': ' Audio CD'}       []
# 4  {'Format:': ' Audio Cassette'}       []
#
#                                             also_buy  \
# 0  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 1  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 2  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 3  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 4  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
#
#                                            also_view  \
# 0  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 1  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 2  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 3  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 4  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
#
#                                             main_cat similar_item
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....

# %%
digi_muse_c.shape
# Out:
# (80891, 19)

# %%
##changing data type
digi_muse_c['rank']= digi_muse_c['rank'].astype(int)
digi_muse_c['price'] = digi_muse_c['price'].apply(pd.to_numeric,errors='coerce')

# %%
digi_muse_c.head(10)
# Out:
#          asin                                            summary  \
# 0  7019098606                                          Uplifting
# 1  7019098606                                         Five Stars
# 2  7019098606  I enjoy listening to it as well as and singing...
# 3  7019098606                                         Five Stars
# 4  7019098606                                  I really love it!
# 5  7019098606                                         Live Again
# 6  7019098606                                         Uplifting!
# 7  7019098606                                    thank you jesus
# 8  7019098606                          great cd at a great price
# 9  7019098606                    best of the Brooklyn Tabernacle
#
#                                           reviewText description  \
# 0  Brooklyn Tab can not be beat in gospel music. ...          []
# 1                                             Great!          []
# 2  Their music is always inspiring! I enjoy liste...          []
# 3                                    Beautiful songs          []
# 4        It's one of my favorites! I really love it!          []
# 5  This is an excellent CD. The CD was in good co...          []
# 6  The Brooklyn Tabernacle Choir has been a minis...          []
# 7  this is a must have cd to start the day.  you ...          []
# 8  I have been looking for the cd for so long and...          []
# 9  This is my favorite CD from the Brooklyn Taber...          []
#
#           title  overall                      brand    rank  verified  \
# 0  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 1  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 2  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 3  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 4  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 5  Live...Again        5  Brooklyn Tabernacle Choir  725231     False
# 6  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 7  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 8  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 9  Live...Again        5  Brooklyn Tabernacle Choir  725231     False
#
#        reviewerID         reviewerName reviewTime  price  \
# 0  A2KLYLMS27MMSX            C. oliver 2014-12-12  13.71
# 1  A1IOEZDAZD6X51                  Raf 2014-12-09  13.71
# 2  A1LUTAW6O69PQP  Paula Milo-Moultrie 2014-12-05  13.71
# 3  A1UUCVS78RELYW             jadamtam 2014-09-29  13.71
# 4  A1E2OY42QMGRXR       Chester Thrash 2014-09-06  13.71
# 5  A3W527BN42AXN1                 Resa 2012-12-29  13.71
# 6  A1QS1CO7GHQ6EJ        Georgia Peach 2012-06-13  13.71
# 7  A349TJMZWT77ZZ            mark dale 2012-06-04  13.71
# 8   A87FAOGM1F70X                  rox 2011-12-23  13.71
# 9  A2K5I4RAQ30IKI          Kevin Quinn 2004-06-09  13.71
#
#                             style category  \
# 0        {'Format:': ' Audio CD'}       []
# 1        {'Format:': ' Audio CD'}       []
# 2        {'Format:': ' Audio CD'}       []
# 3        {'Format:': ' Audio CD'}       []
# 4  {'Format:': ' Audio Cassette'}       []
# 5        {'Format:': ' Audio CD'}       []
# 6        {'Format:': ' Audio CD'}       []
# 7        {'Format:': ' Audio CD'}       []
# 8        {'Format:': ' Audio CD'}       []
# 9        {'Format:': ' Audio CD'}       []
#
#                                             also_buy  \
# 0  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 1  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 2  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 3  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 4  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 5  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 6  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 7  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 8  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 9  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
#
#                                            also_view  \
# 0  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 1  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 2  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 3  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 4  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 5  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 6  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 7  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 8  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 9  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
#
#                                             main_cat similar_item
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
# 5  <img src="https://images-na.ssl-images-amazon....
# 6  <img src="https://images-na.ssl-images-amazon....
# 7  <img src="https://images-na.ssl-images-amazon....
# 8  <img src="https://images-na.ssl-images-amazon....
# 9  <img src="https://images-na.ssl-images-amazon....

# %%
digi_muse_c.shape
# Out:
# (80891, 19)

# %%
print('Data type of merge data:\n',digi_muse_c.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80891 entries, 0 to 140821
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   asin          80891 non-null  object
#  1   summary       80891 non-null  object
#  2   reviewText    80891 non-null  object
#  3   description   80891 non-null  object
#  4   title         80891 non-null  object
#  5   overall       80891 non-null  int64
#  6   brand         80891 non-null  object
#  7   rank          80891 non-null  int32
#  8   verified      80891 non-null  bool
#  9   reviewerID    80891 non-null  object
#  10  reviewerName  80891 non-null  object
#  11  reviewTime    80891 non-null  datetime64[ns]
#  12  price         79501 non-null  float64
#  13  style         80891 non-null  object
#  14  category      80891 non-null  object
#  15  also_buy      80891 non-null  object
#  16  also_view     80891 non-null  object
#  17  main_cat      80891 non-null  object
#  18  similar_item  80891 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(1), int32(1), int64(1), object(14)
# memory usage: 11.5+ MB
# Data type of merge data:
#  None

# %% [markdown]
# ### Cleaning the style columns

# %%
digi_muse_c[['style']]
# Out:
#                                  style
# 0             {'Format:': ' Audio CD'}
# 1             {'Format:': ' Audio CD'}
# 2             {'Format:': ' Audio CD'}
# 3             {'Format:': ' Audio CD'}
# 4       {'Format:': ' Audio Cassette'}
# ...                                ...
# 140814        {'Format:': ' Audio CD'}
# 140815        {'Format:': ' Audio CD'}
# 140819        {'Format:': ' Audio CD'}
# 140820        {'Format:': ' Audio CD'}
# 140821        {'Format:': ' Audio CD'}
#
# [80891 rows x 1 columns]

# %%
style= list(digi_muse_c['style'].items())
style
# Out:
# [(0, {'Format:': ' Audio CD'}),
#  (1, {'Format:': ' Audio CD'}),
#  (2, {'Format:': ' Audio CD'}),
#  (3, {'Format:': ' Audio CD'}),
#  (4, {'Format:': ' Audio Cassette'}),
#  (5, {'Format:': ' Audio CD'}),
#  (6, {'Format:': ' Audio CD'}),
#  (7, {'Format:': ' Audio CD'}),
#  (8, {'Format:': ' Audio CD'}),
#  (9, {'Format:': ' Audio CD'}),
#  (10, {'Format:': ' Audio CD'}),
#  (11, {'Format:': ' Audio CD'}),
#  (12, {'Format:': ' Audio CD'}),
#  (13, {'Format:': ' Audio CD'}),
#  (14, {'Format:': ' Audio CD'}),
#  (15, {'Format:': ' Audio CD'}),
#  (16, {'Format:': ' Audio CD'}),
#  (17, {'Format:': ' Audio CD'}),
#  (18, {'Format:': ' Audio CD'}),
#  (19, {'Format:': ' Audio Cassette'}),
#  (74, {'Format:': ' Audio CD'}),
#  (75, {'Format:': ' Audio CD'}),
#  (76, {'Format:': ' Audio CD'}),
#  (77, {'Format:': ' MP3 Music'}),
#  (78, {'Format:': ' Audio CD'}),
#  (79, {'Format:': ' Audio CD'}),
#  (80, {'Format:': ' Audio CD'}),
#  (81, {'Format:': ' Audio CD'}),
#  (82, {'Format:': ' Audio CD'}),
#  (83, {'Format:': ' Audio CD'}),
#  (84, {'Format:': ' Audio CD'}),
#  (85, {'Format:': ' Audio CD'}),
#  (86, {'Format:': ' Audio CD'}),
#  (1691, {'Format:': ' Audio CD'}),
#  (1692, {'Format:': ' Audio CD'}),
#  (1693, {'Format:': ' Audio CD'}),
#  (1694, {'Format:': ' Audio CD'}),
#  (1695, {'Format:': ' Audio CD'}),
#  (1696, {'Format:': ' Audio CD'}),
#  (1697, {'Format:': ' Audio CD'}),
#  (1698, {'Format:': ' Audio CD'}),
#  (1699, {'Format:': ' Audio CD'}),
#  (1700, {'Format:': ' Audio CD'}),
#  (1701, {'Format:': ' Audio CD'}),
#  (1702, {'Format:': ' Audio CD'}),
#  (1703, {'Format:': ' Audio CD'}),
#  (1704, {'Format:': ' Audio CD'}),
#  (1705, {'Format:': ' Audio CD'}),
#  (1706, {'Format:': ' Audio CD'}),
#  (1707, {'Format:': ' Audio CD'}),
#  (1708, {'Format:': ' Audio CD'}),
#  (1709, {'Format:': ' Audio CD'}),
#  (1710, {'Format:': ' MP3 Music'}),
#  (1711, {'Format:': ' MP3 Music'}),
#  (1712, {'Format:': ' Audio CD'}),
#  (1713, {'Format:': ' Audio CD'}),
#  (1714, {'Format:': ' MP3 Music'}),
#  (1715, {'Format:': ' Audio CD'}),
#  (1716, {'Format:': ' MP3 Music'}),
#  (1717, {'Format:': ' Audio CD'}),
#  (1718, {'Format:': ' Audio CD'}),
#  (1719, {'Format:': ' Audio CD'}),
#  (1720, {'Format:': ' Audio CD'}),
#  (1721, {'Format:': ' Audio CD'}),
#  (1722, {'Format:': ' Audio CD'}),
#  (1723, {'Format:': ' Audio CD'}),
#  (1724, {'Format:': ' Audio CD'}),
#  (1725, {'Format:': ' Audio CD'}),
#  (1726, {'Format:': ' Audio CD'}),
#  (1727, {'Format:': ' Audio CD'}),
#  (1728, {'Format:': ' Audio CD'}),
#  (1729, {'Format:': ' Audio CD'}),
#  (1730, {'Format:': ' Audio CD'}),
#  (1731, {'Format:': ' Audio CD'}),
#  (1732, {'Format:': ' Audio CD'}),
#  (1733, {'Format:': ' Audio CD'}),
#  (1734, {'Format:': ' Audio CD'}),
#  (1735, {'Format:': ' Audio CD'}),
#  (1736, {'Format:': ' Audio CD'}),
#  (1737, {'Format:': ' Audio CD'}),
#  (1738, {'Format:': ' Audio CD'}),
#  (1739, {'Format:': ' Audio CD'}),
#  (1740, {'Format:': ' Audio CD'}),
#  (1741, {'Format:': ' Audio CD'}),
#  (1742, {'Format:': ' Audio CD'}),
#  (1743, {'Format:': ' Audio CD'}),
#  (1744, {'Format:': ' Audio CD'}),
#  (1745, {'Format:': ' Audio CD'}),
#  (1746, {'Format:': ' Audio CD'}),
#  (1747, {'Format:': ' Audio CD'}),
#  (1748, {'Format:': ' Audio CD'}),
#  (1749, {'Format:': ' Audio CD'}),
#  (1750, {'Format:': ' Audio CD'}),
#  (1751, {'Format:': ' Audio CD'}),
#  (1752, {'Format:': ' Audio CD'}),
#  (1753, {'Format:': ' Audio CD'}),
#  (1754, {'Format:': ' Audio CD'}),
#  (1755, {'Format:': ' Audio CD'}),
#  (1756, {'Format:': ' Audio CD'}),
#  (1757, {'Format:': ' Audio CD'}),
#  (1758, {'Format:': ' Audio CD'}),
#  (1759, {'Format:': ' Audio CD'}),
#  (1760, {'Format:': ' Audio CD'}),
#  (1761, {'Format:': ' Audio CD'}),
#  (1762, {'Format:': ' Audio CD'}),
#  (1763, {'Format:': ' Audio CD'}),
#  (1764, {'Format:': ' Audio CD'}),
#  (1765, {'Format:': ' Audio CD'}),
#  (1766, {'Format:': ' Audio CD'}),
#  (1767, {'Format:': ' Audio CD'}),
#  (1768, {'Format:': ' Audio CD'}),
#  (1769, {'Format:': ' Audio CD'}),
#  (1770, {'Format:': ' Audio CD'}),
#  (1771, {'Format:': ' Audio CD'}),
#  (1772, {'Format:': ' Audio CD'}),
#  (1773, {'Format:': ' Audio CD'}),
#  (1774, {'Format:': ' Audio CD'}),
#  (1775, {'Format:': ' Audio CD'}),
#  (1776, {'Format:': ' Audio CD'}),
#  (1777, {'Format:': ' Audio CD'}),
#  (1778, {'Format:': ' Audio CD'}),
#  (1779, {'Format:': ' Audio CD'}),
#  (1780, {'Format:': ' Audio CD'}),
#  (1781, {'Format:': ' Audio CD'}),
#  (1782, {'Format:': ' Audio CD'}),
#  (1783, {'Format:': ' Audio CD'}),
#  (1784, {'Format:': ' Audio CD'}),
#  (1785, {'Format:': ' Audio CD'}),
#  (1786, {'Format:': ' Audio CD'}),
#  (1787, {'Format:': ' Audio CD'}),
#  (1788, {'Format:': ' Vinyl'}),
#  (1789, {'Format:': ' Audio CD'}),
#  (1790, {'Format:': ' Audio CD'}),
#  (1791, {'Format:': ' Audio CD'}),
#  (1792, {'Format:': ' Audio CD'}),
#  (1793, {'Format:': ' Audio CD'}),
#  (1794, {'Format:': ' Audio CD'}),
#  (1795, {'Format:': ' Audio CD'}),
#  (1796, {'Format:': ' Audio CD'}),
#  (1797, {'Format:': ' Audio CD'}),
#  (1947, {'Format:': ' Audio CD'}),
#  (1948, {'Format:': ' Audio CD'}),
#  (1949, {'Format:': ' Audio CD'}),
#  (1950, {'Format:': ' Audio CD'}),
#  (1951, {'Format:': ' Audio CD'}),
#  (1952, {'Format:': ' Audio CD'}),
#  (1953, {'Format:': ' Audio CD'}),
#  (1954, {'Format:': ' Audio CD'}),
#  (1955, {'Format:': ' Audio CD'}),
#  (1956, {'Format:': ' Audio CD'}),
#  (1957, {'Format:': ' Audio CD'}),
#  (1958, {'Format:': ' Audio CD'}),
#  (1959, {'Format:': ' Audio CD'}),
#  (1960, {'Format:': ' Audio CD'}),
#  (1961, {'Format:': ' Audio CD'}),
#  (1962, {'Format:': ' Audio CD'}),
#  (1963, {'Format:': ' Audio CD'}),
#  (1964, {'Format:': ' Audio CD'}),
#  (1965, {'Format:': ' Audio CD'}),
#  (1966, {'Format:': ' Audio CD'}),
#  (1967, {'Format:': ' Audio CD'}),
#  (1968, {'Format:': ' Audio CD'}),
#  (1969, {'Format:': ' Audio CD'}),
#  (1970, {'Format:': ' Audio CD'}),
#  (1971, {'Format:': ' Audio CD'}),
#  (1972, {'Format:': ' Audio CD'}),
#  (1973, {'Format:': ' Audio CD'}),
#  (1974, {'Format:': ' Audio CD'}),
#  (1975, {'Format:': ' Audio CD'}),
#  (1976, {'Format:': ' Audio CD'}),
#  (1977, {'Format:': ' Audio CD'}),
#  (1978, {'Format:': ' Audio CD'}),
#  (1979, {'Format:': ' Audio CD'}),
#  (1980, {'Format:': ' Audio CD'}),
#  (1981, {'Format:': ' Audio CD'}),
#  (1982, {'Format:': ' Audio CD'}),
#  (1983, {'Format:': ' Audio CD'}),
#  (1984, {'Format:': ' Audio CD'}),
#  (1985, {'Format:': ' Audio CD'}),
#  (1986, {'Format:': ' Audio CD'}),
#  (1987, {'Format:': ' Audio CD'}),
#  (1988, {'Format:': ' Audio CD'}),
#  (1989, {'Format:': ' Audio CD'}),
#  (1990, {'Format:': ' Audio CD'}),
#  (1991, {'Format:': ' Audio CD'}),
#  (1992, {'Format:': ' Audio CD'}),
#  (1993, {'Format:': ' Audio CD'}),
#  (1994, {'Format:': ' MP3 Music'}),
#  (1995, {'Format:': ' Audio CD'}),
#  (1996, {'Format:': ' Audio CD'}),
#  (1997, {'Format:': ' Audio CD'}),
#  (1998, {'Format:': ' Audio CD'}),
#  (1999, {'Format:': ' Audio CD'}),
#  (2000, {'Format:': ' Audio CD'}),
#  (2001, {'Format:': ' Audio CD'}),
#  (2002, {'Format:': ' Audio CD'}),
#  (2003, {'Format:': ' Audio CD'}),
#  (2004, {'Format:': ' Audio CD'}),
#  (2005, {'Format:': ' Audio CD'}),
#  (2006, {'Format:': ' MP3 Music'}),
#  (2007, {'Format:': ' Audio CD'}),
#  (2008, {'Format:': ' Audio CD'}),
#  (2009, {'Format:': ' Vinyl'}),
#  (2010, {'Format:': ' Audio CD'}),
#  (2011, {'Format:': ' Audio CD'}),
#  (2012, {'Format:': ' Audio CD'}),
#  (2033, {'Format:': ' Audio CD'}),
#  (2034, {'Format:': ' Audio CD'}),
#  (2035, {'Format:': ' Audio CD'}),
#  (2036, {'Format:': ' Audio CD'}),
#  (2037, {'Format:': ' Audio CD'}),
#  (2038, {'Format:': ' Audio CD'}),
#  (2039, {'Format:': ' Audio CD'}),
#  (2040, {'Format:': ' Audio CD'}),
#  (2041, {'Format:': ' Audio CD'}),
#  (2042, {'Format:': ' Audio CD'}),
#  (2043, {'Format:': ' Audio CD'}),
#  (2044, {'Format:': ' Audio CD'}),
#  (2045, {'Format:': ' Audio CD'}),
#  (2046, {'Format:': ' Audio CD'}),
#  (2047, {'Format:': ' Audio CD'}),
#  (2048, {'Format:': ' Audio CD'}),
#  (2049, {'Format:': ' Audio CD'}),
#  (2050, {'Format:': ' Audio CD'}),
#  (2051, {'Format:': ' Audio CD'}),
#  (2052, {'Format:': ' Audio CD'}),
#  (2053, {'Format:': ' Audio CD'}),
#  (2054, {'Format:': ' Audio CD'}),
#  (2055, {'Format:': ' Audio CD'}),
#  (2056, {'Format:': ' Audio CD'}),
#  (2057, {'Format:': ' Audio CD'}),
#  (2058, {'Format:': ' Audio CD'}),
#  (2059, {'Format:': ' Audio CD'}),
#  (2060, {'Format:': ' Audio CD'}),
#  (2061, {'Format:': ' Audio CD'}),
#  (2062, {'Format:': ' Audio CD'}),
#  (2063, {'Format:': ' Audio CD'}),
#  (2064, {'Format:': ' Audio CD'}),
#  (2065, {'Format:': ' Audio CD'}),
#  (2066, {'Format:': ' Audio CD'}),
#  (2067, {'Format:': ' Audio CD'}),
#  (2068, {'Format:': ' Audio CD'}),
#  (2069, {'Format:': ' Audio CD'}),
#  (2070, {'Format:': ' Audio CD'}),
#  (2071, {'Format:': ' Audio CD'}),
#  (2072, {'Format:': ' Audio CD'}),
#  (2073, {'Format:': ' Audio CD'}),
#  (2074, {'Format:': ' Audio CD'}),
#  (2075, {'Format:': ' Audio CD'}),
#  (2076, {'Format:': ' Audio CD'}),
#  (2077, {'Format:': ' Audio CD'}),
#  (2078, {'Format:': ' Audio CD'}),
#  (2079, {'Format:': ' Audio CD'}),
#  (2080, {'Format:': ' Audio CD'}),
#  (2081, {'Format:': ' Audio CD'}),
#  (2082, {'Format:': ' Audio CD'}),
#  (2083, {'Format:': ' Audio CD'}),
#  (2084, {'Format:': ' Audio CD'}),
#  (2085, {'Format:': ' Audio CD'}),
#  (2086, {'Format:': ' Audio CD'}),
#  (2087, {'Format:': ' Audio CD'}),
#  (2088, {'Format:': ' Audio CD'}),
#  (2089, {'Format:': ' Audio CD'}),
#  (2090, {'Format:': ' Audio CD'}),
#  (2091, {'Format:': ' Audio CD'}),
#  (2092, {'Format:': ' Audio CD'}),
#  (2093, {'Format:': ' Audio CD'}),
#  (2094, {'Format:': ' Audio CD'}),
#  (2095, {'Format:': ' Audio CD'}),
#  (2096, {'Format:': ' Audio CD'}),
#  (2097, {'Format:': ' Audio CD'}),
#  (2098, {'Format:': ' Audio CD'}),
#  (2099, {'Format:': ' MP3 Music'}),
#  (2100, {'Format:': ' Audio CD'}),
#  (2101, {'Format:': ' Audio CD'}),
#  (2102, {'Format:': ' Audio CD'}),
#  (2103, {'Format:': ' Audio CD'}),
#  (2104, {'Format:': ' Audio CD'}),
#  (2105, {'Format:': ' Audio CD'}),
#  (2106, {'Format:': ' Audio CD'}),
#  (2107, {'Format:': ' Audio CD'}),
#  (2108, {'Format:': ' Vinyl'}),
#  (2109, {'Format:': ' Audio CD'}),
#  (2110, {'Format:': ' Audio CD'}),
#  (2111, {'Format:': ' Audio CD'}),
#  (2112, {'Format:': ' Audio CD'}),
#  (2113, {'Format:': ' Audio CD'}),
#  (2114, {'Format:': ' Audio CD'}),
#  (2115, {'Format:': ' Audio CD'}),
#  (2116, {'Format:': ' Audio CD'}),
#  (2117, {'Format:': ' Audio CD'}),
#  (2118, {'Format:': ' Audio CD'}),
#  (2119, {'Format:': ' Audio CD'}),
#  (2120, {'Format:': ' Audio CD'}),
#  (2121, {'Format:': ' Audio CD'}),
#  (2122, {'Format:': ' Audio CD'}),
#  (2123, {'Format:': ' Audio CD'}),
#  (2124, {'Format:': ' Audio CD'}),
#  (2125, {'Format:': ' Audio CD'}),
#  (2126, {'Format:': ' Audio CD'}),
#  (2127, {'Format:': ' Audio CD'}),
#  (2128, {'Format:': ' Audio CD'}),
#  (2129, {'Format:': ' Audio CD'}),
#  (2130, {'Format:': ' Audio CD'}),
#  (2131, {'Format:': ' Audio CD'}),
#  (2132, {'Format:': ' Audio CD'}),
#  (2133, {'Format:': ' Audio CD'}),
#  (2134, {'Format:': ' Audio CD'}),
#  (2135, {'Format:': ' Audio CD'}),
#  (2136, {'Format:': ' Audio CD'}),
#  (2137, {'Format:': ' Audio CD'}),
#  (2138, {'Format:': ' Audio CD'}),
#  (2139, {'Format:': ' Audio CD'}),
#  (2140, {'Format:': ' Audio CD'}),
#  (2141, {'Format:': ' Audio CD'}),
#  (2142, {'Format:': ' Audio CD'}),
#  (2143, {'Format:': ' Audio CD'}),
#  (2144, {'Format:': ' Audio CD'}),
#  (2145, {'Format:': ' Audio CD'}),
#  (2146, {'Format:': ' Audio CD'}),
#  (2147, {'Format:': ' Audio CD'}),
#  (2148, {'Format:': ' Audio CD'}),
#  (2149, {'Format:': ' Audio CD'}),
#  (2150, {'Format:': ' Audio CD'}),
#  (2151, {'Format:': ' Audio CD'}),
#  (2152, {'Format:': ' Audio CD'}),
#  (2153, {'Format:': ' Audio CD'}),
#  (2154, {'Format:': ' Audio CD'}),
#  (2155, {'Format:': ' Audio CD'}),
#  (2156, {'Format:': ' Audio CD'}),
#  (2157, {'Format:': ' Audio CD'}),
#  (2158, {'Format:': ' Audio CD'}),
#  (2159, {'Format:': ' Audio CD'}),
#  (2160, {'Format:': ' Audio CD'}),
#  (2161, {'Format:': ' Audio CD'}),
#  (2162, {'Format:': ' Audio CD'}),
#  (2163, {'Format:': ' Audio CD'}),
#  (2164, {'Format:': ' Audio CD'}),
#  (2165, {'Format:': ' Audio CD'}),
#  (2166, {'Format:': ' Audio CD'}),
#  (2167, {'Format:': ' Audio CD'}),
#  (2168, {'Format:': ' Audio CD'}),
#  (2169, {'Format:': ' Audio CD'}),
#  (2170, {'Format:': ' Audio CD'}),
#  (2171, {'Format:': ' Audio CD'}),
#  (2172, {'Format:': ' Audio CD'}),
#  (2173, {'Format:': ' Audio CD'}),
#  (2174, {'Format:': ' Audio CD'}),
#  (2175, {'Format:': ' Audio CD'}),
#  (2176, {'Format:': ' Audio CD'}),
#  (2177, {'Format:': ' Audio CD'}),
#  (2178, {'Format:': ' Audio CD'}),
#  (2179, {'Format:': ' Audio CD'}),
#  (2180, {'Format:': ' Audio CD'}),
#  (2181, {'Format:': ' Audio CD'}),
#  (2182, {'Format:': ' Audio CD'}),
#  (2183, {'Format:': ' Audio CD'}),
#  (2184, {'Format:': ' Audio CD'}),
#  (2185, {'Format:': ' Audio CD'}),
#  (2186, {'Format:': ' Audio CD'}),
#  (2187, {'Format:': ' Audio CD'}),
#  (2188, {'Format:': ' Audio CD'}),
#  (2189, {'Format:': ' Audio CD'}),
#  (2190, {'Format:': ' Audio CD'}),
#  (2192, {'Format:': ' Audio CD'}),
#  (2193, {'Format:': ' Audio CD'}),
#  (2194, {'Format:': ' Audio CD'}),
#  (2195, {'Format:': ' Audio CD'}),
#  (2196, {'Format:': ' Audio CD'}),
#  (2197, {'Format:': ' Audio CD'}),
#  (2198, {'Format:': ' Audio CD'}),
#  (2199, {'Format:': ' Audio CD'}),
#  (2200, {'Format:': ' MP3 Music'}),
#  (2201, {'Format:': ' Audio CD'}),
#  (2202, {'Format:': ' Audio CD'}),
#  (2203, {'Format:': ' Audio CD'}),
#  (2204, {'Format:': ' Audio CD'}),
#  (2205, {'Format:': ' Audio CD'}),
#  (2206, {'Format:': ' Audio CD'}),
#  (2207, {'Format:': ' Audio CD'}),
#  (2208, {'Format:': ' Audio CD'}),
#  (2209, {'Format:': ' Audio CD'}),
#  (2210, {'Format:': ' Audio CD'}),
#  (2211, {'Format:': ' Audio CD'}),
#  (2212, {'Format:': ' Audio CD'}),
#  (2213, {'Format:': ' Audio CD'}),
#  (2214, {'Format:': ' Audio CD'}),
#  (2215, {'Format:': ' Audio CD'}),
#  (2216, {'Format:': ' Audio CD'}),
#  (2217, {'Format:': ' Audio CD'}),
#  (2218, {'Format:': ' Audio CD'}),
#  (2219, {'Format:': ' Audio CD'}),
#  (2220, {'Format:': ' Audio CD'}),
#  (2221, {'Format:': ' Audio CD'}),
#  (2222, {'Format:': ' Audio CD'}),
#  (2223, {'Format:': ' MP3 Music'}),
#  (2224, {'Format:': ' Audio CD'}),
#  (2225, {'Format:': ' MP3 Music'}),
#  (2226, {'Format:': ' Audio CD'}),
#  (2227, {'Format:': ' Audio CD'}),
#  (2228, {'Format:': ' MP3 Music'}),
#  (2229, {'Format:': ' MP3 Music'}),
#  (2230, {'Format:': ' Audio CD'}),
#  (2231, {'Format:': ' Audio CD'}),
#  (2232, {'Format:': ' Audio CD'}),
#  (2247, {'Format:': ' MP3 Music'}),
#  (2248, {'Format:': ' Audio CD'}),
#  (2249, {'Format:': ' Audio CD'}),
#  (2250, {'Format:': ' Audio CD'}),
#  (2251, {'Format:': ' Audio CD'}),
#  (2252, {'Format:': ' Audio Cassette'}),
#  (2253, {'Format:': ' MP3 Music'}),
#  (2254, {'Format:': ' Audio CD'}),
#  (2255, {'Format:': ' Audio CD'}),
#  (2256, {'Format:': ' MP3 Music'}),
#  (2257, {'Format:': ' MP3 Music'}),
#  (2258, {'Format:': ' Vinyl'}),
#  (2259, {'Format:': ' Audio CD'}),
#  (2260, {'Format:': ' Audio CD'}),
#  (2261, {'Format:': ' Audio CD'}),
#  (2262, {'Format:': ' MP3 Music'}),
#  (2263, {'Format:': ' MP3 Music'}),
#  (2264, {'Format:': ' Audio CD'}),
#  (2265, {'Format:': ' Audio CD'}),
#  (2266, {'Format:': ' Audio CD'}),
#  (2267, {'Format:': ' Audio CD'}),
#  (2268, {'Format:': ' Audio CD'}),
#  (2269, {'Format:': ' Audio CD'}),
#  (2270, {'Format:': ' Audio CD'}),
#  (2271, {'Format:': ' Audio CD'}),
#  (2272, {'Format:': ' Audio CD'}),
#  (2273, {'Format:': ' Audio CD'}),
#  (2274, {'Format:': ' Audio CD'}),
#  (2275, {'Format:': ' Audio CD'}),
#  (2276, {'Format:': ' Audio CD'}),
#  (2277, {'Format:': ' Audio CD'}),
#  (2278, {'Format:': ' Audio CD'}),
#  (2279, {'Format:': ' Audio CD'}),
#  (2280, {'Format:': ' Audio CD'}),
#  (2281, {'Format:': ' Audio CD'}),
#  (2282, {'Format:': ' Audio CD'}),
#  (2283, {'Format:': ' Audio CD'}),
#  (2284, {'Format:': ' Audio CD'}),
#  (2285, {'Format:': ' Audio CD'}),
#  (2286, {'Format:': ' Audio CD'}),
#  (2287, {'Format:': ' Audio CD'}),
#  (2288, {'Format:': ' Audio CD'}),
#  (2289, {'Format:': ' Audio CD'}),
#  (2290, {'Format:': ' Audio CD'}),
#  (2291, {'Format:': ' Audio CD'}),
#  (2292, {'Format:': ' Audio CD'}),
#  (2293, {'Format:': ' Audio CD'}),
#  (2294, {'Format:': ' Audio CD'}),
#  (2295, {'Format:': ' Audio CD'}),
#  (2296, {'Format:': ' Audio CD'}),
#  (2297, {'Format:': ' Audio CD'}),
#  (2298, {'Format:': ' Audio CD'}),
#  (2299, {'Format:': ' Audio CD'}),
#  (2300, {'Format:': ' Audio CD'}),
#  (2301, {'Format:': ' Audio CD'}),
#  (2302, {'Format:': ' Audio CD'}),
#  (2303, {'Format:': ' Audio CD'}),
#  (2304, {'Format:': ' Audio CD'}),
#  (2305, {'Format:': ' Audio CD'}),
#  (2306, {'Format:': ' Audio CD'}),
#  (2307, {'Format:': ' Audio CD'}),
#  (2308, {'Format:': ' Audio CD'}),
#  (2309, {'Format:': ' Audio CD'}),
#  (2310, {'Format:': ' Audio CD'}),
#  (2311, {'Format:': ' Audio CD'}),
#  (2312, {'Format:': ' Audio CD'}),
#  (2313, {'Format:': ' Audio CD'}),
#  (2314, {'Format:': ' Audio CD'}),
#  (2315, {'Format:': ' Audio CD'}),
#  (2316, {'Format:': ' Audio CD'}),
#  (2317, {'Format:': ' Audio CD'}),
#  (2318, {'Format:': ' Audio CD'}),
#  (2319, {'Format:': ' Audio CD'}),
#  (2320, {'Format:': ' Audio CD'}),
#  (2321, {'Format:': ' Audio CD'}),
#  (2322, {'Format:': ' Audio CD'}),
#  (2323, {'Format:': ' Audio CD'}),
#  (2324, {'Format:': ' Audio CD'}),
#  (2325, {'Format:': ' Audio CD'}),
#  (2326, {'Format:': ' Audio CD'}),
#  (2327, {'Format:': ' Audio CD'}),
#  (2328, {'Format:': ' Audio CD'}),
#  (2329, {'Format:': ' Audio CD'}),
#  (2330, {'Format:': ' Audio CD'}),
#  (2331, {'Format:': ' Audio CD'}),
#  (2332, {'Format:': ' Audio CD'}),
#  (2333, {'Format:': ' Audio CD'}),
#  (2334, {'Format:': ' Audio CD'}),
#  (2335, {'Format:': ' Audio CD'}),
#  (2336, {'Format:': ' Audio CD'}),
#  (2337, {'Format:': ' Audio CD'}),
#  (2338, {'Format:': ' Audio CD'}),
#  (2339, {'Format:': ' Audio CD'}),
#  (2340, {'Format:': ' Audio CD'}),
#  (2341, {'Format:': ' Audio CD'}),
#  (2342, {'Format:': ' Audio CD'}),
#  (2343, {'Format:': ' Audio CD'}),
#  (2344, {'Format:': ' Audio CD'}),
#  (2345, {'Format:': ' Audio CD'}),
#  (2346, {'Format:': ' Audio CD'}),
#  (2347, {'Format:': ' Audio CD'}),
#  (2348, {'Format:': ' MP3 Music'}),
#  (2349, {'Format:': ' Audio CD'}),
#  (2351, {'Format:': ' Audio CD'}),
#  (2353, {'Format:': ' Audio CD'}),
#  (2355, {'Format:': ' Audio CD'}),
#  (2357, {'Format:': ' Audio CD'}),
#  (2359, {'Format:': ' Audio CD'}),
#  (2361, {'Format:': ' Audio CD'}),
#  (2363, {'Format:': ' Audio CD'}),
#  (2365, {'Format:': ' Audio CD'}),
#  (2367, {'Format:': ' Audio CD'}),
#  (2369, {'Format:': ' Audio CD'}),
#  (2371, {'Format:': ' Audio CD'}),
#  (2373, {'Format:': ' MP3 Music'}),
#  (2374, {'Format:': ' MP3 Music'}),
#  (2375, {'Format:': ' MP3 Music'}),
#  (2376, {'Format:': ' MP3 Music'}),
#  (2377, {'Format:': ' MP3 Music'}),
#  (2378, {'Format:': ' Audio Cassette'}),
#  (2379, {'Format:': ' MP3 Music'}),
#  (2380, {'Format:': ' Audio Cassette'}),
#  (2381, {'Format:': ' MP3 Music'}),
#  (2382, {'Format:': ' MP3 Music'}),
#  (2383, {'Format:': ' MP3 Music'}),
#  (2384, {'Format:': ' MP3 Music'}),
#  (2385, {'Format:': ' MP3 Music'}),
#  (2386, {'Format:': ' MP3 Music'}),
#  (2387, {'Format:': ' MP3 Music'}),
#  (2388, {'Format:': ' MP3 Music'}),
#  (2389, {'Format:': ' MP3 Music'}),
#  (2390, {'Format:': ' MP3 Music'}),
#  (2391, {'Format:': ' Audio CD'}),
#  (2392, {'Format:': ' MP3 Music'}),
#  (2393, {'Format:': ' Audio CD'}),
#  (2394, {'Format:': ' MP3 Music'}),
#  (2395, {'Format:': ' MP3 Music'}),
#  (2396, {'Format:': ' Audio CD'}),
#  (2397, {'Format:': ' MP3 Music'}),
#  (2398, {'Format:': ' MP3 Music'}),
#  (2399, {'Format:': ' Audio CD'}),
#  (2400, {'Format:': ' MP3 Music'}),
#  (2401, {'Format:': ' MP3 Music'}),
#  (2402, {'Format:': ' MP3 Music'}),
#  (2403, {'Format:': ' MP3 Music'}),
#  (2404, {'Format:': ' Audio CD'}),
#  (2405, {'Format:': ' MP3 Music'}),
#  (2406, {'Format:': ' MP3 Music'}),
#  (2407, {'Format:': ' MP3 Music'}),
#  (2408, {'Format:': ' Audio CD'}),
#  (2409, {'Format:': ' MP3 Music'}),
#  (2410, {'Format:': ' MP3 Music'}),
#  (2411, {'Format:': ' MP3 Music'}),
#  (2412, {'Format:': ' Audio CD'}),
#  (2413, {'Format:': ' MP3 Music'}),
#  (2414, {'Format:': ' Audio CD'}),
#  (2415, {'Format:': ' MP3 Music'}),
#  (2416, {'Format:': ' Audio CD'}),
#  (2417, {'Format:': ' Audio CD'}),
#  (2418, {'Format:': ' Audio CD'}),
#  (2419, {'Format:': ' Audio CD'}),
#  (2420, {'Format:': ' Audio CD'}),
#  (2421, {'Format:': ' Audio CD'}),
#  (2422, {'Format:': ' Audio CD'}),
#  (2423, {'Format:': ' Audio CD'}),
#  (2424, {'Format:': ' Audio CD'}),
#  (2425, {'Format:': ' Audio CD'}),
#  (2426, {'Format:': ' Audio CD'}),
#  (2427, {'Format:': ' Audio CD'}),
#  (2428, {'Format:': ' Audio CD'}),
#  (2429, {'Format:': ' Audio CD'}),
#  (2430, {'Format:': ' Audio CD'}),
#  (2431, {'Format:': ' Audio CD'}),
#  (2432, {'Format:': ' Audio CD'}),
#  (2433, {'Format:': ' Audio CD'}),
#  (2434, {'Format:': ' Audio CD'}),
#  (2435, {'Format:': ' Audio CD'}),
#  (2436, {'Format:': ' Audio CD'}),
#  (2437, {'Format:': ' Audio CD'}),
#  (2438, {'Format:': ' Audio CD'}),
#  (2439, {'Format:': ' Audio CD'}),
#  (2440, {'Format:': ' Audio CD'}),
#  (2441, {'Format:': ' Audio CD'}),
#  (2442, {'Format:': ' Audio CD'}),
#  (2443, {'Format:': ' Audio CD'}),
#  (2444, {'Format:': ' Audio CD'}),
#  (2445, {'Format:': ' Audio CD'}),
#  (2446, {'Format:': ' Audio CD'}),
#  (2447, {'Format:': ' Audio CD'}),
#  (2448, {'Format:': ' Audio CD'}),
#  (2449, {'Format:': ' Audio CD'}),
#  (2450, {'Format:': ' Audio CD'}),
#  (2451, {'Format:': ' Audio CD'}),
#  (2452, {'Format:': ' Audio CD'}),
#  (2453, {'Format:': ' Audio CD'}),
#  (2454, {'Format:': ' Audio CD'}),
#  (2455, {'Format:': ' MP3 Music'}),
#  (2456, {'Format:': ' MP3 Music'}),
#  (2457, {'Format:': ' MP3 Music'}),
#  (2458, {'Format:': ' MP3 Music'}),
#  (2459, {'Format:': ' Audio CD'}),
#  (2460, {'Format:': ' Audio Cassette'}),
#  (2461, {'Format:': ' Audio Cassette'}),
#  (2462, {'Format:': ' Audio Cassette'}),
#  (2463, {'Format:': ' Audio Cassette'}),
#  (2514, {'Format:': ' Audio CD'}),
#  (2516, {'Format:': ' Audio CD'}),
#  (2518, {'Format:': ' Audio CD'}),
#  (2520, {'Format:': ' Audio CD'}),
#  (2522, {'Format:': ' Audio CD'}),
#  (2524, {'Format:': ' Audio CD'}),
#  (2526, {'Format:': ' Audio CD'}),
#  (2528, {'Format:': ' Audio CD'}),
#  (2530, {'Format:': ' Audio CD'}),
#  (2532, {'Format:': ' Audio CD'}),
#  (2534, {'Format:': ' Audio CD'}),
#  (2536, {'Format:': ' Audio CD'}),
#  (2538, {'Format:': ' Audio CD'}),
#  (2540, {'Format:': ' Audio CD'}),
#  (2542, {'Format:': ' Audio CD'}),
#  (2544, {'Format:': ' Audio CD'}),
#  (2546, {'Format:': ' Audio CD'}),
#  (2548, {'Format:': ' Audio CD'}),
#  (2550, {'Format:': ' Audio CD'}),
#  (2552, {'Format:': ' Audio CD'}),
#  (2622, {'Format:': ' Audio CD'}),
#  (2624, {'Format:': ' Audio CD'}),
#  (2626, {'Format:': ' Audio CD'}),
#  (2628, {'Format:': ' Audio CD'}),
#  (2630, {'Format:': ' Audio CD'}),
#  (2632, {'Format:': ' Audio CD'}),
#  (2634, {'Format:': ' Audio CD'}),
#  (2636, {'Format:': ' Audio CD'}),
#  (2638, {'Format:': ' Audio CD'}),
#  (2640, {'Format:': ' Audio CD'}),
#  (2642, {'Format:': ' Audio CD'}),
#  (2666, {'Format:': ' Audio CD'}),
#  (2668, {'Format:': ' Audio CD'}),
#  (2670, {'Format:': ' Audio CD'}),
#  (2672, {'Format:': ' Audio CD'}),
#  (2674, {'Format:': ' Audio CD'}),
#  (2676, {'Format:': ' Audio CD'}),
#  (2678, {'Format:': ' Audio CD'}),
#  (2680, {'Format:': ' Audio CD'}),
#  (2682, {'Format:': ' Audio CD'}),
#  (2684, {'Format:': ' Audio CD'}),
#  (2686, {'Format:': ' Audio CD'}),
#  (2688, {'Format:': ' Audio CD'}),
#  (2690, {'Format:': ' Audio CD'}),
#  (2692, {'Format:': ' Audio CD'}),
#  (2694, {'Format:': ' Audio CD'}),
#  (2696, {'Format:': ' Audio CD'}),
#  (2698, {'Format:': ' Audio CD'}),
#  (2700, {'Format:': ' Audio CD'}),
#  (2702, {'Format:': ' Audio CD'}),
#  (2704, {'Format:': ' Audio CD'}),
#  (2706, {'Format:': ' Audio CD'}),
#  (2708, {'Format:': ' Audio CD'}),
#  (2710, {'Format:': ' Audio CD'}),
#  (2712, {'Format:': ' Audio CD'}),
#  (2714, {'Format:': ' Audio CD'}),
#  (2716, {'Format:': ' Audio CD'}),
#  (2718, {'Format:': ' Audio CD'}),
#  (2720, {'Format:': ' Audio CD'}),
#  (2722, {'Format:': ' Audio CD'}),
#  (2724, {'Format:': ' Audio CD'}),
#  (2726, {'Format:': ' Audio CD'}),
#  (2728, {'Format:': ' Audio CD'}),
#  (2730, {'Format:': ' Audio CD'}),
#  (2732, {'Format:': ' Audio CD'}),
#  (2734, {'Format:': ' Audio CD'}),
#  (2736, {'Format:': ' Audio CD'}),
#  (2738, {'Format:': ' Audio CD'}),
#  (2740, {'Format:': ' Audio CD'}),
#  (2770, {'Format:': ' Audio CD'}),
#  (2772, {'Format:': ' Audio CD'}),
#  (2774, {'Format:': ' Audio CD'}),
#  (2776, {'Format:': ' Audio CD'}),
#  (2778, {'Format:': ' Audio CD'}),
#  (2780, {'Format:': ' Audio CD'}),
#  (2782, {'Format:': ' Audio CD'}),
#  (2784, {'Format:': ' Audio CD'}),
#  (2786, {'Format:': ' Audio CD'}),
#  (2788, {'Format:': ' Audio CD'}),
#  (2790, {'Format:': ' Audio CD'}),
#  (2792, {'Format:': ' Audio CD'}),
#  (2794, {'Format:': ' Audio CD'}),
#  (2796, {'Format:': ' Audio CD'}),
#  (2798, {'Format:': ' Audio CD'}),
#  (2800, {'Format:': ' Audio CD'}),
#  (2802, {'Format:': ' Audio CD'}),
#  (2804, {'Format:': ' Audio CD'}),
#  (2806, {'Format:': ' Audio CD'}),
#  (2808, {'Format:': ' Audio CD'}),
#  (2810, {'Format:': ' Audio CD'}),
#  (2812, {'Format:': ' Audio CD'}),
#  (2814, {'Format:': ' Audio CD'}),
#  (2816, {'Format:': ' Audio CD'}),
#  (2818, {'Format:': ' Audio CD'}),
#  (2820, {'Format:': ' Audio CD'}),
#  (2822, {'Format:': ' Audio CD'}),
#  (2824, {'Format:': ' Audio CD'}),
#  (2826, {'Format:': ' Audio CD'}),
#  (2828, {'Format:': ' Audio CD'}),
#  (2830, {'Format:': ' Audio CD'}),
#  (2832, {'Format:': ' Audio CD'}),
#  (2834, {'Format:': ' Audio CD'}),
#  (2836, {'Format:': ' Audio CD'}),
#  (2838, {'Format:': ' Audio CD'}),
#  (2840, {'Format:': ' Audio CD'}),
#  (2842, {'Format:': ' Audio CD'}),
#  (2844, {'Format:': ' Audio CD'}),
#  (2846, {'Format:': ' Audio CD'}),
#  (2848, {'Format:': ' Audio CD'}),
#  (2850, {'Format:': ' Audio CD'}),
#  (2852, {'Format:': ' Audio CD'}),
#  (2854, {'Format:': ' Audio CD'}),
#  (2856, {'Format:': ' Audio CD'}),
#  (2858, {'Format:': ' Audio CD'}),
#  (2860, {'Format:': ' Audio CD'}),
#  (2862, {'Format:': ' Audio CD'}),
#  (2864, {'Format:': ' Audio CD'}),
#  (2866, {'Format:': ' Audio CD'}),
#  (2868, {'Format:': ' Audio CD'}),
#  (2870, {'Format:': ' Audio CD'}),
#  (2872, {'Format:': ' Audio CD'}),
#  (2874, {'Format:': ' Audio CD'}),
#  (2876, {'Format:': ' Audio CD'}),
#  (2878, {'Format:': ' Audio CD'}),
#  (2880, {'Format:': ' Audio CD'}),
#  (2882, {'Format:': ' Audio CD'}),
#  (2884, {'Format:': ' Audio CD'}),
#  (2908, {'Format:': ' Audio CD'}),
#  (2910, {'Format:': ' Audio CD'}),
#  (2912, {'Format:': ' Audio CD'}),
#  (2914, {'Format:': ' Audio CD'}),
#  (2916, {'Format:': ' Audio CD'}),
#  (2918, {'Format:': ' MP3 Music'}),
#  (2920, {'Format:': ' Audio CD'}),
#  (2922, {'Format:': ' MP3 Music'}),
#  (2924, {'Format:': ' Audio CD'}),
#  (2926, {'Format:': ' Audio CD'}),
#  (2928, {'Format:': ' Audio CD'}),
#  (2930, {'Format:': ' Audio CD'}),
#  (2932, {'Format:': ' Audio CD'}),
#  (2934, {'Format:': ' Audio CD'}),
#  (2936, {'Format:': ' Audio CD'}),
#  (2938, {'Format:': ' Audio CD'}),
#  (2940, {'Format:': ' Audio CD'}),
#  (2942, {'Format:': ' Audio CD'}),
#  (2944, {'Format:': ' Audio CD'}),
#  (2946, {'Format:': ' Audio CD'}),
#  (2948, {'Format:': ' Audio CD'}),
#  (2950, {'Format:': ' Audio CD'}),
#  (2952, {'Format:': ' Audio CD'}),
#  (2954, {'Format:': ' MP3 Music'}),
#  (2956, {'Format:': ' MP3 Music'}),
#  (2958, {'Format:': ' MP3 Music'}),
#  (2960, {'Format:': ' Audio CD'}),
#  (2962, {'Format:': ' Audio CD'}),
#  (2964, {'Format:': ' Audio CD'}),
#  (2966, {'Format:': ' MP3 Music'}),
#  (2968, {'Format:': ' MP3 Music'}),
#  (2970, {'Format:': ' Audio CD'}),
#  (2972, {'Format:': ' Audio CD'}),
#  (2974, {'Format:': ' Audio CD'}),
#  (2976, {'Format:': ' Audio CD'}),
#  (2978, {'Format:': ' Audio CD'}),
#  (2980, {'Format:': ' Audio CD'}),
#  (2982, {'Format:': ' Audio CD'}),
#  (2984, {'Format:': ' Audio CD'}),
#  (2986, {'Format:': ' MP3 Music'}),
#  (2988, {'Format:': ' Audio CD'}),
#  (2990, {'Format:': ' Audio CD'}),
#  (2992, {'Format:': ' Audio CD'}),
#  (2994, {'Format:': ' Audio CD'}),
#  (2996, {'Format:': ' Audio CD'}),
#  (2998, {'Format:': ' Audio CD'}),
#  (3000, {'Format:': ' Audio CD'}),
#  (3002, {'Format:': ' Audio CD'}),
#  (3004, {'Format:': ' Audio CD'}),
#  (3006, {'Format:': ' Audio CD'}),
#  (3008, {'Format:': ' Audio CD'}),
#  (3010, {'Format:': ' Audio CD'}),
#  (3012, {'Format:': ' Audio CD'}),
#  (3014, {'Format:': ' Audio CD'}),
#  (3016, {'Format:': ' Audio CD'}),
#  (3018, {'Format:': ' Audio CD'}),
#  (3020, {'Format:': ' Audio CD'}),
#  (3022, {'Format:': ' Audio CD'}),
#  (3024, {'Format:': ' Audio CD'}),
#  (3026, {'Format:': ' MP3 Music'}),
#  (3028, {'Format:': ' Audio CD'}),
#  (3030, {'Format:': ' Audio CD'}),
#  (3032, {'Format:': ' Audio CD'}),
#  (3034, {'Format:': ' Audio CD'}),
#  (3036, {'Format:': ' Audio CD'}),
#  (3038, {'Format:': ' Audio CD'}),
#  (3040, {'Format:': ' Audio CD'}),
#  (3042, {'Format:': ' Audio CD'}),
#  (3044, {'Format:': ' Audio CD'}),
#  (3046, {'Format:': ' Audio CD'}),
#  (3048, {'Format:': ' Audio CD'}),
#  (3050, {'Format:': ' Audio CD'}),
#  (3052, {'Format:': ' Audio CD'}),
#  (3054, {'Format:': ' Audio CD'}),
#  (3056, {'Format:': ' Audio CD'}),
#  (3058, {'Format:': ' Audio CD'}),
#  (3060, {'Format:': ' Audio CD'}),
#  (3062, {'Format:': ' Audio CD'}),
#  (3064, {'Format:': ' Audio CD'}),
#  (3066, {'Format:': ' Audio CD'}),
#  (3068, {'Format:': ' MP3 Music'}),
#  (3070, {'Format:': ' Audio CD'}),
#  (3072, {'Format:': ' Audio CD'}),
#  (3074, {'Format:': ' Audio CD'}),
#  (3076, {'Format:': ' Audio CD'}),
#  (3078, {'Format:': ' Audio CD'}),
#  (3080, {'Format:': ' Audio CD'}),
#  (3082, {'Format:': ' Audio CD'}),
#  (3084, {'Format:': ' Audio CD'}),
#  (3086, {'Format:': ' Audio CD'}),
#  (3088, {'Format:': ' Audio CD'}),
#  (3090, {'Format:': ' Audio CD'}),
#  (3092, {'Format:': ' Audio CD'}),
#  (3094, {'Format:': ' Audio CD'}),
#  (3096, {'Format:': ' Audio CD'}),
#  (3098, {'Format:': ' Audio CD'}),
#  (3100, {'Format:': ' Audio CD'}),
#  (3102, {'Format:': ' Audio CD'}),
#  (3104, {'Format:': ' Audio CD'}),
#  (3106, {'Format:': ' Audio CD'}),
#  (3108, {'Format:': ' Audio CD'}),
#  (3110, {'Format:': ' Audio CD'}),
#  (3112, {'Format:': ' Audio CD'}),
#  (3114, {'Format:': ' Audio CD'}),
#  (3116, {'Format:': ' Audio CD'}),
#  (3118, {'Format:': ' Audio CD'}),
#  (3120, {'Format:': ' Audio CD'}),
#  (3122, {'Format:': ' Audio CD'}),
#  (3124, {'Format:': ' Audio CD'}),
#  (3126, {'Format:': ' Audio CD'}),
#  (3128, {'Format:': ' Audio CD'}),
#  (3130, {'Format:': ' MP3 Music'}),
#  (3132, {'Format:': ' MP3 Music'}),
#  (3134, {'Format:': ' Audio CD'}),
#  (3136, {'Format:': ' MP3 Music'}),
#  (3138, {'Format:': ' Audio CD'}),
#  (3140, {'Format:': ' MP3 Music'}),
#  (3142, {'Format:': ' MP3 Music'}),
#  (3144, {'Format:': ' MP3 Music'}),
#  (3146, {'Format:': ' Audio CD'}),
#  (3148, {'Format:': ' Audio CD'}),
#  (3150, {'Format:': ' Audio CD'}),
#  (3152, {'Format:': ' Audio CD'}),
#  (3154, {'Format:': ' Audio CD'}),
#  (3156, {'Format:': ' Audio CD'}),
#  (3158, {'Format:': ' Audio CD'}),
#  (3160, {'Format:': ' Audio CD'}),
#  (3162, {'Format:': ' Audio CD'}),
#  (3164, {'Format:': ' Audio CD'}),
#  (3166, {'Format:': ' Audio CD'}),
#  (3168, {'Format:': ' Audio CD'}),
#  (3170, {'Format:': ' Audio CD'}),
#  (3172, {'Format:': ' Audio CD'}),
#  (3174, {'Format:': ' Audio CD'}),
#  (3176, {'Format:': ' Audio CD'}),
#  (3178, {'Format:': ' Audio CD'}),
#  (3180, {'Format:': ' Audio CD'}),
#  (3182, {'Format:': ' Audio Cassette'}),
#  (3184, {'Format:': ' Audio CD'}),
#  (3186, {'Format:': ' Audio CD'}),
#  (3188, {'Format:': ' Audio CD'}),
#  (3190, {'Format:': ' Audio CD'}),
#  (3192, {'Format:': ' Audio CD'}),
#  (3194, {'Format:': ' Audio CD'}),
#  (3196, {'Format:': ' Audio CD'}),
#  (3198, {'Format:': ' Audio CD'}),
#  (3200, {'Format:': ' Audio CD'}),
#  (3202, {'Format:': ' Audio CD'}),
#  (3204, {'Format:': ' Audio CD'}),
#  (3206, {'Format:': ' Audio CD'}),
#  (3208, {'Format:': ' Audio CD'}),
#  (3276, {'Format:': ' Audio CD'}),
#  (3278, {'Format:': ' Audio CD'}),
#  (3280, {'Format:': ' Audio CD'}),
#  (3282, {'Format:': ' Audio CD'}),
#  (3284, {'Format:': ' Audio CD'}),
#  (3286, {'Format:': ' Audio CD'}),
#  (3288, {'Format:': ' Audio CD'}),
#  (3290, {'Format:': ' Audio CD'}),
#  (3292, {'Format:': ' Audio CD'}),
#  (3294, {'Format:': ' Audio CD'}),
#  (3296, {'Format:': ' MP3 Music'}),
#  (3298, {'Format:': ' Audio CD'}),
#  (3300, {'Format:': ' Audio CD'}),
#  (3302, {'Format:': ' Audio CD'}),
#  (3304, {'Format:': ' Audio CD'}),
#  (3306, {'Format:': ' Audio CD'}),
#  (3668, {'Format:': ' Audio CD'}),
#  (3670, {'Format:': ' Audio CD'}),
#  (3672, {'Format:': ' Audio CD'}),
#  (3674, {'Format:': ' Audio CD'}),
#  (3676, {'Format:': ' Audio CD'}),
#  (3678, {'Format:': ' Audio CD'}),
#  (3680, {'Format:': ' Audio CD'}),
#  (3682, {'Format:': ' Audio CD'}),
#  (3684, {'Format:': ' Audio CD'}),
#  (3686, {'Format:': ' Audio CD'}),
#  (3688, {'Format:': ' Audio CD'}),
#  (3690, {'Format:': ' Audio CD'}),
#  (3692, {'Format:': ' Audio CD'}),
#  (3694, {'Format:': ' Audio CD'}),
#  (3696, {'Format:': ' Audio CD'}),
#  (3698, {'Format:': ' Audio CD'}),
#  (3700, {'Format:': ' Audio CD'}),
#  (3702, {'Format:': ' Audio CD'}),
#  (3704, {'Format:': ' Audio CD'}),
#  (3706, {'Format:': ' Audio CD'}),
#  (3708, {'Format:': ' Audio CD'}),
#  (3710, {'Format:': ' Audio CD'}),
#  (3712, {'Format:': ' Audio CD'}),
#  (3714, {'Format:': ' Audio CD'}),
#  (3716, {'Format:': ' Audio CD'}),
#  (3718, {'Format:': ' Audio CD'}),
#  (3720, {'Format:': ' Audio CD'}),
#  (3722, {'Format:': ' Audio CD'}),
#  (3724, {'Format:': ' Audio CD'}),
#  (3726, {'Format:': ' Audio CD'}),
#  (3728, {'Format:': ' Audio CD'}),
#  (3730, {'Format:': ' Audio CD'}),
#  (3732, {'Format:': ' Audio CD'}),
#  (3734, {'Format:': ' Audio CD'}),
#  (3736, {'Format:': ' Audio CD'}),
#  (3738, {'Format:': ' Audio CD'}),
#  (3740, {'Format:': ' Audio CD'}),
#  (3742, {'Format:': ' Audio CD'}),
#  (3744, {'Format:': ' Audio CD'}),
#  (3746, {'Format:': ' Audio CD'}),
#  (3748, {'Format:': ' Audio CD'}),
#  (3750, {'Format:': ' Audio CD'}),
#  (3752, {'Format:': ' Audio CD'}),
#  (3754, {'Format:': ' Audio CD'}),
#  (3756, {'Format:': ' Audio CD'}),
#  (3758, {'Format:': ' Audio CD'}),
#  (3760, {'Format:': ' Audio CD'}),
#  (3762, {'Format:': ' Audio CD'}),
#  (3764, {'Format:': ' Audio CD'}),
#  (3766, {'Format:': ' Audio CD'}),
#  (3768, {'Format:': ' Audio CD'}),
#  (3770, {'Format:': ' Audio CD'}),
#  (3772, {'Format:': ' Audio CD'}),
#  (3774, {'Format:': ' Audio CD'}),
#  (3776, {'Format:': ' Audio CD'}),
#  (3778, {'Format:': ' Audio CD'}),
#  (3780, {'Format:': ' Audio CD'}),
#  (3782, {'Format:': ' Audio CD'}),
#  (3784, {'Format:': ' Audio CD'}),
#  (3786, {'Format:': ' Audio CD'}),
#  (3994, {'Format:': ' Audio CD'}),
#  (3996, {'Format:': ' Audio CD'}),
#  (3998, {'Format:': ' Audio CD'}),
#  (4000, {'Format:': ' Audio CD'}),
#  (4002, {'Format:': ' MP3 Music'}),
#  (4004, {'Format:': ' Audio CD'}),
#  (4006, {'Format:': ' Audio CD'}),
#  (4008, {'Format:': ' Audio CD'}),
#  (4010, {'Format:': ' Audio CD'}),
#  (4012, {'Format:': ' Audio CD'}),
#  (4014, {'Format:': ' Audio CD'}),
#  (4016, {'Format:': ' Audio CD'}),
#  (4018, {'Format:': ' Audio CD'}),
#  (4020, {'Format:': ' Audio CD'}),
#  (4022, {'Format:': ' Audio CD'}),
#  (4024, {'Format:': ' Audio CD'}),
#  (4026, {'Format:': ' Audio CD'}),
#  (4028, {'Format:': ' MP3 Music'}),
#  (4030, {'Format:': ' Audio CD'}),
#  (4032, {'Format:': ' Audio CD'}),
#  (4034, {'Format:': ' Audio CD'}),
#  (4036, {'Format:': ' Audio CD'}),
#  (4038, {'Format:': ' Audio CD'}),
#  (4040, {'Format:': ' Audio CD'}),
#  (4042, {'Format:': ' Audio CD'}),
#  (4044, {'Format:': ' Audio CD'}),
#  (4046, {'Format:': ' Audio CD'}),
#  (4048, {'Format:': ' Audio CD'}),
#  (4050, {'Format:': ' MP3 Music'}),
#  (4052, {'Format:': ' Audio CD'}),
#  (4054, {'Format:': ' Audio CD'}),
#  (4056, {'Format:': ' MP3 Music'}),
#  (4058, {'Format:': ' Audio CD'}),
#  (4060, {'Format:': ' Audio CD'}),
#  (4062, {'Format:': ' Audio CD'}),
#  (4064, {'Format:': ' Audio CD'}),
#  ...]

# %%
#digi_muse_c.loc[digi_muse_c["style"].str[0] != "$", "price"] = "unknown"
#digi_muse_c.loc[digi_muse_c["style"].str.contains('-'), "price"] = "unknown"
digi_muse_c['style'].replace("size",'', regex=True, inplace=True)
digi_muse_c['style'].replace([":","''"],'', regex=True, inplace=True)
#digi_muse_c.fillna("unknown",inplace = True)

# %%
# Define function to clean dictionary string
def clean_dict_string(s):
    # Remove leading/trailing whitespace and curly braces
    s = s.str.strip('{}').strip()
    return s

# %%
digi_muse_c['style'] = digi_muse_c['style'].apply(lambda x: json.dumps(x)[1:-1])

# %%
digi_muse_c['style'].replace(["Size","Color"],'', regex=True, inplace=True)
digi_muse_c['style'].replace([":","''"],'', regex=True, inplace=True)
digi_muse_c['style'].replace(r'[^a-zA-Z0-9\s]','', regex=True, inplace=True)

# %%
digi_muse_c['style'].replace(r'\s+', ' ', regex=True, inplace=True)

# %%
print(list(digi_muse_c['style']))
# Out:
# ['Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio Cassette', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio Cassette', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format MP3 Music', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format MP3 Music', 'Format MP3 Music', 'Format Audio CD', 'Format Audio CD', 'Format MP3 Music', 'Format Audio CD', 'Format MP3 Music', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Vinyl', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format MP3 Music', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format MP3 Music', 'Format Audio CD', 'Format Audio CD', 'Format Vinyl', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio CD', 'Format Audio C ...

# %%
digi_muse_c['style'].value_counts()
# Out:
# Format Audio CD                 62668
# Format Vinyl                     9941
# Format MP3 Music                 7167
# Format DVD                        363
# Format Audio Cassette             359
# Format DVD Audio                  139
# Format Bluray Audio                88
# Format Hardcover                   44
# Format Bluray                      40
# Format Paperback                   20
# Format Amazon Video                12
# Format USB Memory Stick            12
# Format Unknown Binding              6
# Format Mass Market Paperback        5
# Format CDROM                        5
# Format VHS Tape                     5
# Format Vinyl Bound                  4
# Format Prime Video                  3
# Format Video CD                     3
# Format MP3 CD                       2
# Format Unbound                      1
# Format CD Video                     1
# Format Misc Supplies                1
# Format CDR                          1
# Format Kitchen                      1
# Name: style, dtype: int64

# %%
digi_muse_c.head(10)
# Out:
#          asin                                            summary  \
# 0  7019098606                                          Uplifting
# 1  7019098606                                         Five Stars
# 2  7019098606  I enjoy listening to it as well as and singing...
# 3  7019098606                                         Five Stars
# 4  7019098606                                  I really love it!
# 5  7019098606                                         Live Again
# 6  7019098606                                         Uplifting!
# 7  7019098606                                    thank you jesus
# 8  7019098606                          great cd at a great price
# 9  7019098606                    best of the Brooklyn Tabernacle
#
#                                           reviewText description  \
# 0  Brooklyn Tab can not be beat in gospel music. ...          []
# 1                                             Great!          []
# 2  Their music is always inspiring! I enjoy liste...          []
# 3                                    Beautiful songs          []
# 4        It's one of my favorites! I really love it!          []
# 5  This is an excellent CD. The CD was in good co...          []
# 6  The Brooklyn Tabernacle Choir has been a minis...          []
# 7  this is a must have cd to start the day.  you ...          []
# 8  I have been looking for the cd for so long and...          []
# 9  This is my favorite CD from the Brooklyn Taber...          []
#
#           title  overall                      brand    rank  verified  \
# 0  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 1  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 2  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 3  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 4  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 5  Live...Again        5  Brooklyn Tabernacle Choir  725231     False
# 6  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 7  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 8  Live...Again        5  Brooklyn Tabernacle Choir  725231      True
# 9  Live...Again        5  Brooklyn Tabernacle Choir  725231     False
#
#        reviewerID         reviewerName reviewTime  price  \
# 0  A2KLYLMS27MMSX            C. oliver 2014-12-12  13.71
# 1  A1IOEZDAZD6X51                  Raf 2014-12-09  13.71
# 2  A1LUTAW6O69PQP  Paula Milo-Moultrie 2014-12-05  13.71
# 3  A1UUCVS78RELYW             jadamtam 2014-09-29  13.71
# 4  A1E2OY42QMGRXR       Chester Thrash 2014-09-06  13.71
# 5  A3W527BN42AXN1                 Resa 2012-12-29  13.71
# 6  A1QS1CO7GHQ6EJ        Georgia Peach 2012-06-13  13.71
# 7  A349TJMZWT77ZZ            mark dale 2012-06-04  13.71
# 8   A87FAOGM1F70X                  rox 2011-12-23  13.71
# 9  A2K5I4RAQ30IKI          Kevin Quinn 2004-06-09  13.71
#
#                    style category  \
# 0        Format Audio CD       []
# 1        Format Audio CD       []
# 2        Format Audio CD       []
# 3        Format Audio CD       []
# 4  Format Audio Cassette       []
# 5        Format Audio CD       []
# 6        Format Audio CD       []
# 7        Format Audio CD       []
# 8        Format Audio CD       []
# 9        Format Audio CD       []
#
#                                             also_buy  \
# 0  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 1  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 2  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 3  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 4  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 5  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 6  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 7  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 8  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 9  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
#
#                                            also_view  \
# 0  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 1  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 2  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 3  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 4  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 5  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 6  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 7  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 8  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 9  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
#
#                                             main_cat similar_item
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
# 5  <img src="https://images-na.ssl-images-amazon....
# 6  <img src="https://images-na.ssl-images-amazon....
# 7  <img src="https://images-na.ssl-images-amazon....
# 8  <img src="https://images-na.ssl-images-amazon....
# 9  <img src="https://images-na.ssl-images-amazon....

# %%
digi_muse_c.shape
# Out:
# (80891, 19)

# %% [markdown]
# ### Combining(concatenating) review text and review summary columns

# %%
digi_muse_c['Review'] = digi_muse_c['reviewText'] + digi_muse_c['summary']
digi_muse_c = digi_muse_c.drop(['reviewText','summary'], axis=1)
digi_muse_c.shape
# Out:
# (80891, 18)

# %%
digi_muse_c.head(1)
# Out:
#          asin description         title  overall                      brand  \
# 0  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
#
#      rank  verified      reviewerID reviewerName reviewTime  price  \
# 0  725231      True  A2KLYLMS27MMSX    C. oliver 2014-12-12  13.71
#
#              style category  \
# 0  Format Audio CD       []
#
#                                             also_buy  \
# 0  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
#
#                                            also_view  \
# 0  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
#
#                                               Review
# 0  Brooklyn Tab can not be beat in gospel music. ...

# %% [markdown]
# ### Data cleaning and removing special characters

# %%
def clean_text(text):
    # remove any non-alphanumeric characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # convert all text to lower case
    text = text.lower()
    # remove any URLs
    text = re.sub(r'http\S+', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    # remove any email addresses
    text = re.sub(r'\S+@\S+', '', text)
    # remove any numbers, digits, and hyphens
    text = re.sub(r'[0-9\-]+', '', text)
    #: Removes any punctuation marks from the string.
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    #Removes any newline characters.
    text = re.sub('\n', '', text)
    # remove any extra white space
    text = re.sub(r'\s+', ' ', text)
    # remove leading and trailing white space
    text = text.strip()
    return text

# %%
digi_muse_c['Review'] = digi_muse_c['Review'].apply(lambda x:clean_text(x))
digi_muse_c[['Review']]
# Out:
#                                                    Review
# 0       brooklyn tab can not be beat in gospel music t...
# 1                                         greatfive stars
# 2       their music is always inspiring i enjoy listen...
# 3                               beautiful songsfive stars
# 4       its one of my favorites i really love iti real...
# ...                                                   ...
# 140814  i always like to hear philip glass on solo pia...
# 140815  an excellent choice of pieces covering the hig...
# 140819                          i love covenantfive stars
# 140820                           pretty good epfour stars
# 140821  michael davis is so hip and respected that the...
#
# [80891 rows x 1 columns]

# %% [markdown]
# ### Removing stop words

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS                     # Importing stop words from English language.
print('Number of stop words: %d' % len(spacy_stopwords))
# Out:
# Number of stop words: 326

# %%
print(spacy_stopwords)
# Out:
# {'of', 'itself', 'hence', 'cannot', 'neither', 'what', 'into', 'should', 'our', 'whatever', 'latterly', 'sixty', 'two', 'if', 'behind', 'three', 'its', 'yet', 'either', 'same', 'never', 'n’t', 'toward', 'some', 'make', 'always', 'moreover', "'re", "'d", 'mostly', 'amongst', 'wherein', 'former', 'them', 'one', 'third', 'along', 'does', 'thru', 'since', 'about', 'him', 'someone', 'hundred', 'whereafter', "'ve", 'everything', 'by', 'beforehand', 'becoming', 'serious', 'must', 'back', 'well', 'off', 'were', 'after', 'then', 'again', 'as', 'who', 'sometime', 'five', 'himself', 'than', 'still', 'last', '‘ll', 'thereby', 'using', 'an', 'ours', 'this', 'might', 'can', 'nine', 'my', 'not', 'except', '’m', 'further', 'see', 'only', 'everywhere', 'we', 'yourselves', 'whereupon', 'first', 'whether', '’ll', 'already', 'is', 'how', 'take', 'though', 'both', 'through', 'which', 'top', 'hereafter', 'next', 'nowhere', 'used', 'could', 'across', 'become', 'above', 'none', 'upon', 'she', 'no', 'whence', 'ca', 'he', 'because', 'indeed', '’d', 'but', 'alone', '‘d', 'done', 'onto', 'these', 'namely', 'anything', 'once', 'or', 'against', 'nothing', 'most', 'do', 'too', 'therefore', 'on', 'ten', 'fifteen', 'over', 'below', 'eleven', 'another', 'afterwards', 'yours', 'anywhere', 'somehow', 'formerly', 'there', 'show', '‘ve', 'several', 'yourself', 'part', 'all', 'perhaps', 'whole', 'get', 'made', 'until', 'for', 'that', 'a', 'twelve', 'various', 'via', 'am', 'others', 'keep', 'before', 'more', 'six', 'say', 'any', 'would', 'seems', 'enough', 'hers', 'being', 'the', 'within', 'whose', 'became', 'whereas', 'four', 'very', 'thereafter', 'been', 'anyhow', 'many', 'has', 'quite', 'without', 'it', '‘re', 'front', 'may', 'mine', 'rather', 'however', 'really', 'here', 'nobody', '‘s', 'bottom', 'thence', 'when', 'unless', '’ve', 'just', 'whither', 'nevertheless', 'forty', 'call', 'around', "n't", 'thereupon', 'nor', '‘m', 'among', 'out', 'ever', 'becomes', 'themselves', 'something', 'with', 'beside', 'herein', 'much', 'sometimes', 'have', 'towards', 'be', 'at', 'anyway', 're', 'to', 'and', 'regarding', 'beyond', 'give', 'other', 'down', 'latter', 'her', 'fifty', 'such', 'besides', 'i', 'those', 'per', 'move', 'so', 'are', 'why', 'under', 'noone', 'where', 'seeming', '’re', 'up', 'although', 'will', 'n‘t', 'they', "'ll", "'s", 'his', 'between', 'name', 'throughout', 'hereupon', 'from', 'you', 'otherwise', 'almost', "'m", 'everyone', 'whom', 'myself', 'amount', 'seemed', 'herself', 'whoever', 'your', 'least', 'together', 'wherever', 'empty', 'seem', 'please', 'go', 'each', 'often', 'while', 'even', 'ourselves', 'now', 'less', 'somewhere', 'full', 'side', 'in', 'us', 'elsewhere', 'every', 'me', 'had', 'whenever', 'their', 'thus', 'put', 'anyone', 'also', 'else', 'doing', 'did', 'eight', 'whereby', 'during', 'few', 'meanwhile', 'twenty', 'due', 'was', 'hereby', '’s', 'own', 'therein'}

# %%
'five' in spacy_stopwords
# Out:
# True

# %%
'stars' in spacy_stopwords
# Out:
# False

# %%
excluding = ['against','not','don', "don't",'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't",
             'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 
             'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't",'shouldn', "shouldn't", 'wasn',
             "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't",'empty','enough','could','good','except','bad','five',
             'star','pretty','better','smooth','uneven']
stop_words = [words for words in spacy_stopwords if words not in excluding]

# %%
print('Number of stop words: %d' % len(stop_words))
# Out:
# Number of stop words: 319

# %%
digi_muse_c['Review'] = digi_muse_c['Review'].apply(lambda x: ' '.join([i for i in x.split() if i not in stop_words]))

# %%
def lemma(text):
    tokens = nlp(text.lower())
  #Lemmatization

    final=[]
    for word in tokens:
        final.append(word.lemma_) 
    text = " ".join(final)
    return text

# %%
digi_muse_c['Review'] = digi_muse_c['Review'].apply(lambda x:lemma(x))
digi_muse_c['Review']
# Out:
# 0         brooklyn tab not beat gospel music sing kind w...
# 1                                            greatfive star
# 2         music inspire enjoy listen singing alongi enjo...
# 3                                  beautiful songsfive star
# 4                                    favorite love iti love
#                                 ...
# 140814    like hear philip glass solo piano solo piano v...
# 140815    excellent choice piece cover high point einste...
# 140819                               love covenantfive star
# 140820                              pretty good epfour star
# 140821    michael davis hip respect trombonist rolling s...
# Name: Review, Length: 80891, dtype: object

# %% [markdown]
# # Sentiment distribution based on polarity scores

# %% [markdown]
# ### TextBlob:- determing sentiments by creating polarity score of Review-Text

# %%
# Create a new column for sentiment polarity scores
digi_muse_c["polarity"] = digi_muse_c["Review"].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
digi_muse_c["polarity"]
# Out:
# 0         0.700000
# 1         0.000000
# 2         0.400000
# 3         0.850000
# 4         0.500000
#             ...
# 140814    0.425000
# 140815    0.419184
# 140819    0.500000
# 140820    0.475000
# 140821    0.157870
# Name: polarity, Length: 80891, dtype: float64

# %%
def pos_neg(score):
    
    '''Returns the sentiment of the polarity'''
    
    if score < 0:
        sentiment_type = 'Negative'
    elif score == 0:
        sentiment_type = 'Neutral'
    else:
        sentiment_type = 'Positive'
        
    return sentiment_type

# %%
digi_muse_c['Sentiment'] = digi_muse_c['polarity'].apply(pos_neg)

# %%
digi_muse_c.head(10)
# Out:
#          asin description         title  overall                      brand  \
# 0  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
# 1  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
# 2  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
# 3  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
# 4  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
# 5  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
# 6  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
# 7  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
# 8  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
# 9  7019098606          []  Live...Again        5  Brooklyn Tabernacle Choir
#
#      rank  verified      reviewerID         reviewerName reviewTime  price  \
# 0  725231      True  A2KLYLMS27MMSX            C. oliver 2014-12-12  13.71
# 1  725231      True  A1IOEZDAZD6X51                  Raf 2014-12-09  13.71
# 2  725231      True  A1LUTAW6O69PQP  Paula Milo-Moultrie 2014-12-05  13.71
# 3  725231      True  A1UUCVS78RELYW             jadamtam 2014-09-29  13.71
# 4  725231      True  A1E2OY42QMGRXR       Chester Thrash 2014-09-06  13.71
# 5  725231     False  A3W527BN42AXN1                 Resa 2012-12-29  13.71
# 6  725231      True  A1QS1CO7GHQ6EJ        Georgia Peach 2012-06-13  13.71
# 7  725231      True  A349TJMZWT77ZZ            mark dale 2012-06-04  13.71
# 8  725231      True   A87FAOGM1F70X                  rox 2011-12-23  13.71
# 9  725231     False  A2K5I4RAQ30IKI          Kevin Quinn 2004-06-09  13.71
#
#                    style category  \
# 0        Format Audio CD       []
# 1        Format Audio CD       []
# 2        Format Audio CD       []
# 3        Format Audio CD       []
# 4  Format Audio Cassette       []
# 5        Format Audio CD       []
# 6        Format Audio CD       []
# 7        Format Audio CD       []
# 8        Format Audio CD       []
# 9        Format Audio CD       []
#
#                                             also_buy  \
# 0  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 1  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 2  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 3  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 4  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 5  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 6  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 7  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 8  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
# 9  [B00004R8SJ, B00SLEJI78, B000002MJ3, B079PDJSR...
#
#                                            also_view  \
# 0  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 1  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 2  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 3  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 4  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 5  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 6  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 7  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 8  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
# 9  [B00004R8SJ, B079PDJSRJ, B00SLEJI78, B0000DZ3C...
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
# 5  <img src="https://images-na.ssl-images-amazon....
# 6  <img src="https://images-na.ssl-images-amazon....
# 7  <img src="https://images-na.ssl-images-amazon....
# 8  <img src="https://images-na.ssl-images-amazon....
# 9  <img src="https://images-na.ssl-images-amazon....
#
#                                               Review  polarity Sentiment
# 0  brooklyn tab not beat gospel music sing kind w...  0.700000  Positive
# 1                                     greatfive star  0.000000   Neutral
# 2  music inspire enjoy listen singing alongi enjo...  0.400000  Positive
# 3                           beautiful songsfive star  0.850000  Positive
# 4                             favorite love iti love  0.500000  Positive
# 5  excellent cd cd good condition get brooklyn ta...  0.733333  Positive
# 6  brooklyn tabernacle choir ministry year everyt...  0.440000  Positive
# 7  cd start day feel spirit set day like would no...  0.000000   Neutral
# 8  look cd long find amazon amazing issue got scr...  0.450000  Positive
# 9  favorite cd brooklyn tabernacle member love mu...  0.183333  Positive

# %%
digi_muse_c.drop(['description','polarity'],axis=1,inplace=True)

# %%
print('New data shape after drop value:\n',digi_muse_c.shape)
# Out:
# New data shape after drop value:
#  (80891, 18)

# %%
digi_muse_data=digi_muse_c.copy()

# %%
digi_muse_data.columns
# Out:
# Index(['asin', 'title', 'overall', 'brand', 'rank', 'verified', 'reviewerID',
#        'reviewerName', 'reviewTime', 'price', 'style', 'category', 'also_buy',
#        'also_view', 'main_cat', 'similar_item', 'Review', 'Sentiment'],
#       dtype='object')

# %%
digi_muse_data.isnull().sum()
# Out:
# asin               0
# title              0
# overall            0
# brand              0
# rank               0
# verified           0
# reviewerID         0
# reviewerName       0
# reviewTime         0
# price           1390
# style              0
# category           0
# also_buy           0
# also_view          0
# main_cat           0
# similar_item       0
# Review             0
# Sentiment          0
# dtype: int64

# %%
digi_muse_data.dropna(inplace=True)

# %%
digi_muse_data.isnull().sum()
# Out:
# asin            0
# title           0
# overall         0
# brand           0
# rank            0
# verified        0
# reviewerID      0
# reviewerName    0
# reviewTime      0
# price           0
# style           0
# category        0
# also_buy        0
# also_view       0
# main_cat        0
# similar_item    0
# Review          0
# Sentiment       0
# dtype: int64

# %%
digi_muse_data.shape
# Out:
# (79501, 18)

# %%
digi_muse_data.to_csv('Digi_Muse_data.csv')

# %%
df=pd.read_csv('Digi_Muse_data.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# asin                0
# title             591
# overall             0
# brand            7590
# rank                0
# verified            0
# reviewerID          0
# reviewerName        1
# reviewTime          0
# price               0
# style               0
# category            0
# also_buy            0
# also_view           0
# main_cat            0
# similar_item    79501
# Review              2
# Sentiment           0
# dtype: int64
